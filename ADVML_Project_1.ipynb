# %% [markdown]
# <a href="https://colab.research.google.com/github/lizziecao/demo-qmss/blob/main/ADVML_Project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Your Uni : wx3028, LC3913
# # Your Full name : Xiaoyi Wang, Lizhi Cao
# # Link to your Public Github repository with Final report  : https://github.com/SoyaWang/QMSSGR5074_001_2025_1---PROJECTS-IN-ADVANCED-MACHINE-LEARNING

# %% [markdown]
# ### Submission Due Date: 03/07/2025

# %% [markdown]
# # World Happiness Classification Competition
# Goals :
# - Understand how the models function
# - Understand what the parameters control
# - Learn from the model experimentation process
# - Make a good looking notebook report
# - Upload as a personal project on Github
#
# **Overall Steps:**
# 1. Load datasets and merge them.
# 2. Preprocess data using Sklearn Column Transformer/ Write and Save Preprocessor function
# 3. Fit model on preprocessed data and save preprocessor function and model
# 4. Generate predictions from X_test data and submit predictions

# %% [markdown]
# ## 0. Loading Datasets

# %% [markdown]
# Loading the World Happiness 2023 datasets

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Load the dataset
whr_df = pd.read_csv('WHR_2023.csv')

# Inspect the first few rows to understand the structure
whr_df
# Out:
#               country                        region  happiness_score  \
# 0             Finland                Western Europe            7.804
# 1             Denmark                Western Europe            7.586
# 2             Iceland                Western Europe            7.530
# 3              Israel  Middle East and North Africa            7.473
# 4         Netherlands                Western Europe            7.403
# ..                ...                           ...              ...
# 132  Congo (Kinshasa)            Sub-Saharan Africa            3.207
# 133          Zimbabwe            Sub-Saharan Africa            3.204
# 134      Sierra Leone            Sub-Saharan Africa            3.138
# 135           Lebanon  Middle East and North Africa            2.392
# 136       Afghanistan                    South Asia            1.859
#
#      gdp_per_capita  social_support  healthy_life_expectancy  \
# 0             1.888           1.585                    0.535
# 1             1.949           1.548                    0.537
# 2             1.926           1.620                    0.559
# 3             1.833           1.521                    0.577
# 4             1.942           1.488                    0.545
# ..              ...             ...                      ...
# 132           0.531           0.784                    0.105
# 133           0.758           0.881                    0.069
# 134           0.670           0.540                    0.092
# 135           1.417           0.476                    0.398
# 136           0.645           0.000                    0.087
#
#      freedom_to_make_life_choices  generosity  perceptions_of_corruption
# 0                           0.772       0.126                      0.535
# 1                           0.734       0.208                      0.525
# 2                           0.738       0.250                      0.187
# 3                           0.569       0.124                      0.158
# 4                           0.672       0.251                      0.394
# ..                            ...         ...                        ...
# 132                         0.375       0.183                      0.068
# 133                         0.363       0.112                      0.117
# 134                         0.371       0.193                      0.051
# 135                         0.123       0.061                      0.027
# 136                         0.000       0.093                      0.059
#
# [137 rows x 9 columns]

# %%
# Convert the regression target ('happiness_score') into classification labels
# We'll use quartiles to create 5 happiness categories: Very Low, Low, Average, High, Very High

# Define quartiles
whr_df['happiness_category'] = pd.qcut(whr_df['happiness_score'],
                                       q=5,
                                       labels=['Very Low', 'Low', 'Average', 'High', 'Very High'])

# Select features and target
X = whr_df.drop(columns=['happiness_score', 'happiness_category'])
y = whr_df['happiness_category']

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Convert y_train and y_test to numerical labels
y_train_labels = y_train.astype('category').cat.codes
y_test_labels = y_test.astype('category').cat.codes

# %% [markdown]
# Write in the next cell what the y_train.astype('category').cat.codes line does. What is the difference between y_train_labels and y_train?

# %%
# Your answer:
#
# The line "y_train.astype('category').cat.codes" does the following:
# 1. Converts the y_train Series, which contains categorical labels (like "Very Low", "Low", etc.), into a pandas Categorical type.
# 2. Extracts the integer codes corresponding to each category using the .cat.codes attribute.
#
# For example, if y_train contains values such as "Very Low", "Low", "Average", "High", "Very High",
# then after applying .cat.codes, these might be converted to integers like 0, 1, 2, 3, and 4 respectively.
#
# Difference between y_train_labels and y_train:
# - y_train: Contains the original categorical labels (as strings or categorical data) for the happiness categories.
# - y_train_labels: Contains the numerical encoding (integer codes) of those labels, which is useful for
#   machine learning algorithms that require numerical input.

# %% [markdown]
# <h3> Add new data

# %%
# Truncated and cleaned up region data to merge
countrydata=pd.read_csv("newcountryvars.csv")

countrydata.head()
# Out:
#   country_name  population  population_below_poverty_line       hdi  \
# 0        India  1339180127                           21.9  0.623559
# 1      Nigeria   190886311                           70.0  0.527105
# 2       Mexico   129163276                           46.2  0.761683
# 3     Pakistan   197015955                           29.5  0.550354
# 4   Bangladesh   164669751                           31.5  0.578824
#
#    life_expectancy  expected_years_of_schooling  mean_years_of_schooling  \
# 0           68.322                    11.696590                 6.298834
# 1           53.057                     9.970482                 6.000000
# 2           76.972                    13.299090                 8.554985
# 3           66.365                     8.106910                 5.089460
# 4           71.985                    10.178706                 5.241577
#
#             gni
# 0   5663.474799
# 1   5442.901264
# 2  16383.106680
# 3   5031.173074
# 4   3341.490722

# %%
# Merge in new data to X_train and X_test by taking "country" from first table and "country_name" from 2nd table.
# Also check which countries are common in both the datasets, and which type of merge will you perform for the best results.
# Hint: Look on the 'how' parameter of megre function of pandas.
common_countries = set(X_train['country']).intersection(set(countrydata['country_name']))
print("countries in common：", common_countries)

X_train = pd.merge(X_train, countrydata, left_on='country', right_on='country_name', how='left')
X_train.drop(columns=['country_name'], inplace=True)

X_test = pd.merge(X_test, countrydata, left_on='country', right_on='country_name', how='left')
X_test.drop(columns=['country_name'], inplace=True)
# Out:
# countries in common： {'Zimbabwe', 'Bulgaria', 'Spain', 'Peru', 'Belgium', 'Tajikistan', 'United Kingdom', 'Mexico', 'Saudi Arabia', 'China', 'Albania', 'Chile', 'Venezuela', 'Brazil', 'Romania', 'Uganda', 'El Salvador', 'Togo', 'Iceland', 'Zambia', 'Colombia', 'Mongolia', 'Finland', 'Guinea', 'India', 'Malawi', 'Singapore', 'Jamaica', 'Portugal', 'Honduras', 'Kenya', 'Luxembourg', 'Madagascar', 'Pakistan', 'Ghana', 'South Korea', 'Ivory Coast', 'Tanzania', 'Nepal', 'Jordan', 'Italy', 'Indonesia', 'Ethiopia', 'Morocco', 'Comoros', 'Uzbekistan', 'Mauritania', 'Iraq', 'Niger', 'Israel', 'Denmark', 'Sierra Leone', 'Estonia', 'Hungary', 'Slovenia', 'Bolivia', 'Poland', 'Egypt', 'Ukraine', 'Cambodia', 'Mauritius', 'Malta', 'Montenegro', 'Dominican Republic', 'Nigeria', 'Bosnia and Herzegovina', 'Cyprus', 'New Zealand', 'Kosovo', 'Mali', 'Senegal', 'Slovakia', 'Liberia', 'Australia', 'Sri Lanka', 'Thailand', 'Serbia', 'Norway', 'Bahrain', 'Lithuania', 'Netherlands', 'Burkina Faso', 'Namibia', 'Greece', 'Iran', 'Latvia', 'Austria', 'Afghanistan', 'Sweden'}

# %%
X_train.head(1)
# Out:
#       country              region  gdp_per_capita  social_support  \
# 0  Madagascar  Sub-Saharan Africa           0.632           0.779
#
#    healthy_life_expectancy  freedom_to_make_life_choices  generosity  \
# 0                    0.178                         0.187       0.177
#
#    perceptions_of_corruption  gdp_social  population  \
# 0                      0.134    0.492328  25570895.0
#
#    population_below_poverty_line       hdi  life_expectancy  \
# 0                           70.7  0.512149           65.515
#
#    expected_years_of_schooling  mean_years_of_schooling          gni
# 0                     10.34614                 6.145955  1319.699397

# %% [markdown]
# ## 1.  EDA

# %%
print(X_train.dtypes)
# Out:
# country                           object
# region                            object
# gdp_per_capita                   float64
# social_support                   float64
# healthy_life_expectancy          float64
# freedom_to_make_life_choices     float64
# generosity                       float64
# perceptions_of_corruption        float64
# gdp_social                       float64
# population                       float64
# population_below_poverty_line    float64
# hdi                              float64
# life_expectancy                  float64
# expected_years_of_schooling      float64
# mean_years_of_schooling          float64
# gni                              float64
# dtype: object

# %% [markdown]
# Describe what you see above?

# %% [markdown]
# The output shows the data types for each column in your X_train dataset:
#
# Columns country and region are object type columns. These are stored as objects, which typically means they are strings (or categorical data). They represent non-numeric information, like the names of countries and regions.
#
# Columns such as gdp_per_capita, social_support, healthy_life_expectancy, freedom_to_make_life_choices, generosity, perceptions_of_corruption, gdp_social, population, population_below_poverty_line, hdi, life_expectancy, expected_years_of_schooling, mean_years_of_schooling, and gni are all stored as float64.
# This indicates that these features are numerical and are likely continuous variables. They represent various metrics and indicators related to country-level data (like economic, social, and health indicators).

# %% [markdown]
# Find out the number and percentage of missing values in the table per column

# %%
# Your code here:

missing_counts = X_train.isnull().sum()

missing_percentages = (missing_counts / len(X_train)) * 100

missing_info = pd.DataFrame({
    'Missing Count': missing_counts,
    'Missing Percentage': missing_percentages
})

print(missing_info)
# Out:
#                                Missing Count  Missing Percentage
# country                                    0            0.000000
# region                                     0            0.000000
# gdp_per_capita                             0            0.000000
# social_support                             0            0.000000
# healthy_life_expectancy                    0            0.000000
# freedom_to_make_life_choices               0            0.000000
# generosity                                 0            0.000000
# perceptions_of_corruption                  0            0.000000
# population                                 6            6.315789
# population_below_poverty_line             16           16.842105
# hdi                                        6            6.315789
# life_expectancy                            7            7.368421
# expected_years_of_schooling                7            7.368421
# mean_years_of_schooling                    7            7.368421
# gni                                        7            7.368421

# %% [markdown]
# Plot the frequency distribution / histogram of some of the numerical features that you think are important

# %%
# Your plotting code here:
import matplotlib.pyplot as plt

numerical_features = ['gdp_per_capita', 'social_support', 'healthy_life_expectancy', 'freedom_to_make_life_choices']

plt.figure(figsize=(16, 12))

for idx, feature in enumerate(numerical_features):
    plt.subplot(2, 2, idx + 1)
    plt.hist(X_train[feature].dropna(), bins=30, edgecolor='black')
    plt.title(f'Histogram of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# Plot the categorical variables and their distribution

# %%
# Your plotting code here:
categorical_columns = X_train.select_dtypes(include='object').columns

plt.figure(figsize=(16, 4 * len(categorical_columns)))

for i, col in enumerate(categorical_columns):
    plt.subplot(len(categorical_columns), 1, i + 1)
    counts = X_train[col].value_counts()
    counts.plot(kind='bar', edgecolor='black')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# Perform feature correlation analysis to identify relationships between variables. Use Pearson, Spearman, or Kendall correlation coefficients to analyze feature dependencies.

# %%
# Your code here:(using pearson correlation coefficient)
import matplotlib.pyplot as plt
import numpy as np

numeric_features = X_train.select_dtypes(include=[np.number]).columns
pearson_corr = X_train[numeric_features].corr(method='pearson')

print("Pearson Correlation Matrix:")
display(pearson_corr)
# Out:
# Pearson Correlation Matrix:
#                                gdp_per_capita  social_support  \
# gdp_per_capita                       1.000000        0.769394
# social_support                       0.769394        1.000000
# healthy_life_expectancy              0.860164        0.771294
# freedom_to_make_life_choices         0.483145        0.571646
# generosity                          -0.115580        0.084327
# perceptions_of_corruption            0.432076        0.301807
# population                          -0.045583       -0.109651
# population_below_poverty_line       -0.620790       -0.605304
# hdi                                  0.902386        0.855297
# life_expectancy                      0.830886        0.774096
# expected_years_of_schooling          0.820940        0.809587
# mean_years_of_schooling              0.815423        0.845490
# gni                                  0.834177        0.667188
#
#                                healthy_life_expectancy  \
# gdp_per_capita                                0.860164
# social_support                                0.771294
# healthy_life_expectancy                       1.000000
# freedom_to_make_life_choices                  0.441636
# generosity                                   -0.114189
# perceptions_of_corruption                     0.414878
# population                                   -0.043507
# population_below_poverty_line                -0.716390
# hdi                                           0.929456
# life_expectancy                               0.959434
# expected_years_of_schooling                   0.845512
# mean_years_of_schooling                       0.834757
# gni                                           0.769030
#
#                                freedom_to_make_life_choices  generosity  \
# gdp_per_capita                                     0.483145   -0.115580
# social_support                                     0.571646    0.084327
# healthy_life_expectancy                            0.441636   -0.114189
# freedom_to_make_life_choices                       1.000000    0.192401
# generosity                                         0.192401    1.000000
# perceptions_of_corruption                          0.372781    0.105359
# population                                         0.119970    0.025726
# population_below_poverty_line                     -0.476459   -0.058728
# hdi                                                0.519108   -0.065485
# life_expectancy                                    0.514694   -0.105490
# expected_years_of_schooling                        0.453316   -0.028513
# mean_years_of_schooling                            0.468835   -0.005128
# gni                                                0.483939    0.015789
#
#                                perceptions_of_corruption  population  \
# gdp_per_capita                                  0.432076   -0.045583
# social_support                                  0.301807   -0.109651
# healthy_life_expectancy                         0.414878   -0.043507
# freedom_to_make_life_choices                    0.372781    0.119970
# generosity                                      0.105359    0.025726
# perceptions_of_corruption                       1.000000   -0.056750
# population                                     -0.056750    1.000000
# population_below_poverty_line                  -0.181277   -0.140834
# hdi                                             0.421911   -0.065315
# life_expectancy                                 0.414737   -0.041229
# expected_years_of_schooling                     0.398154   -0.086023
# mean_years_of_schooling                         0.399698   -0.118630
# gni                                             0.666834   -0.113701
#
#                                population_below_poverty_line       hdi  \
# gdp_per_capita                                     -0.620790  0.902386
# social_support                                     -0.605304  0.855297
# healthy_life_expectancy                            -0.716390  0.929456
# freedom_to_make_life_choices                       -0.476459  0.519108
# generosity                                         -0.058728 -0.065485
# perceptions_of_corruption                          -0.181277  0.421911
# population                                         -0.140834 -0.065315
# population_below_poverty_line                       1.000000 -0.683361
# hdi                                                -0.683361  1.000000
# life_expectancy                                    -0.719110  0.932439
# expected_years_of_schooling                        -0.582770  0.939177
# mean_years_of_schooling                            -0.579371  0.934324
# gni                                                -0.537597  0.831201
#
#                                life_expectancy  expected_years_of_schooling  \
# gdp_per_capita                        0.830886                     0.820940
# social_support                        0.774096                     0.809587
# healthy_life_expectancy               0.959434                     0.845512
# freedom_to_make_life_choices          0.514694                     0.453316
# generosity                           -0.105490                    -0.028513
# perceptions_of_corruption             0.414737                     0.398154
# population                           -0.041229                    -0.086023
# population_below_poverty_line        -0.719110                    -0.582770
# hdi                                   0.932439                     0.939177
# life_expectancy                       1.000000                     0.852332
# expected_years_of_schooling           0.852332                     1.000000
# mean_years_of_schooling               0.811818                     0.880690
# gni                                   0.764468                     0.751037
#
#                                mean_years_of_schooling       gni
# gdp_per_capita                                0.815423  0.834177
# social_support                                0.845490  0.667188
# healthy_life_expectancy                       0.834757  0.769030
# freedom_to_make_life_choices                  0.468835  0.483939
# generosity                                   -0.005128  0.015789
# perceptions_of_corruption                     0.399698  0.666834
# population                                   -0.118630 -0.113701
# population_below_poverty_line                -0.579371 -0.537597
# hdi                                           0.934324  0.831201
# life_expectancy                               0.811818  0.764468
# expected_years_of_schooling                   0.880690  0.751037
# mean_years_of_schooling                       1.000000  0.731864
# gni                                           0.731864  1.000000

# %% [markdown]
# Explore relationships between variables (bivariate, etc), correlation tables, and how they associate with the target variable.

# %%
# Your plotting code(s) here:

import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

train_data = X_train.copy()
train_data['target'] = y_train

numeric_features = train_data.select_dtypes(include=['int64', 'float64']).columns.tolist()

if 'target' in numeric_features:
    numeric_features.remove('target')

sns.pairplot(train_data, vars=numeric_features, hue='target', diag_kind='kde')
plt.suptitle("Pairwise Relationships among All Numeric Variables", y=1.02)
plt.show()

# %%
# Your plotting code(s) here:
# Plot the Pearson correlation matrix
plt.figure(figsize=(8, 6))
plt.imshow(pearson_corr, cmap='coolwarm', interpolation='none')
plt.colorbar(label='Correlation Coefficient')
plt.xticks(ticks=np.arange(len(numeric_features)), labels=numeric_features, ha='right', rotation=45)
plt.yticks(ticks=np.arange(len(numeric_features)), labels=numeric_features)
plt.title('Feature Correlation Analysis (Pearson)')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import math

ncols = 2
n_features = len(numeric_features)
nrows = math.ceil(n_features / ncols)

plt.figure(figsize=(ncols * 6, nrows * 4))

for i, feature in enumerate(numeric_features):
    plt.subplot(nrows, ncols, i + 1)
    sns.boxplot(data=train_data, x='target', y=feature)
    plt.title(f"{feature} vs Target")
    plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
categorical_features = X_train.select_dtypes(include=['object']).columns.tolist()

categorical_features = X_train.select_dtypes(include=['object']).columns.tolist()

plt.figure(figsize=(20, len(categorical_features) * 3))

for i, feature in enumerate(categorical_features):
    ax = plt.subplot(len(categorical_features), 1, i + 1)
    sns.countplot(data=train_data, x=feature, hue='target', ax=ax)

    ax.set_title(f"{feature} Distribution by Target")

    plt.xticks(rotation=45, ha='right')

    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# Also, detect outliers using box plots, Z-score analysis, or the IQR method to identify potential data anomalies.

# %%
# Your code here(using IQR):
outliers_info = {}

for feature in numeric_features:
    Q1 = X_train[feature].quantile(0.25)
    Q3 = X_train[feature].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = X_train[(X_train[feature] < lower_bound) | (X_train[feature] > upper_bound)]

    outliers_info[feature] = {
        'Lower Bound': lower_bound,
        'Upper Bound': upper_bound,
        'Number of Outliers': outliers.shape[0]
    }

print("Outlier detection using the IQR method:")
for feature, info in outliers_info.items():
    print(f"{feature}: {info}")
# Out:
# Outlier detection using the IQR method:
# gdp_per_capita: {'Lower Bound': 0.0014999999999996128, 'Upper Bound': 2.8975000000000004, 'Number of Outliers': 1}
# social_support: {'Lower Bound': 0.33174999999999977, 'Upper Bound': 2.01375, 'Number of Outliers': 2}
# healthy_life_expectancy: {'Lower Bound': -0.14, 'Upper Bound': 0.892, 'Number of Outliers': 0}
# freedom_to_make_life_choices: {'Lower Bound': 0.15150000000000002, 'Upper Bound': 0.9555, 'Number of Outliers': 3}
# generosity: {'Lower Bound': -0.04525, 'Upper Bound': 0.35675, 'Number of Outliers': 1}
# perceptions_of_corruption: {'Lower Bound': -0.10974999999999999, 'Upper Bound': 0.34024999999999994, 'Number of Outliers': 10}
# population: {'Lower Bound': -39990215.0, 'Upper Bound': 81177457.0, 'Number of Outliers': 9}
# population_below_poverty_line: {'Lower Bound': -15.524999999999991, 'Upper Bound': 65.87499999999999, 'Number of Outliers': 4}
# hdi: {'Lower Bound': 0.1248623015000001, 'Upper Bound': 1.2934486815, 'Number of Outliers': 0}
# life_expectancy: {'Lower Bound': 44.85325, 'Upper Bound': 101.65125, 'Number of Outliers': 0}
# expected_years_of_schooling: {'Lower Bound': 4.035016250000003, 'Upper Bound': 23.147126249999996, 'Number of Outliers': 0}
# mean_years_of_schooling: {'Lower Bound': -1.6162507343750008, 'Upper Bound': 19.130134440625, 'Number of Outliers': 0}
# gni: {'Lower Bound': -32079.707969999996, 'Upper Bound': 62829.85007, 'Number of Outliers': 2}

# %% [markdown]
# Write what you observed and your General comments on what should be done:

# %% [markdown]
# ### Observations
# Relationships Between Variables:
#
# The pairwise scatter plots and correlation heatmaps indicate that some numerical features tend to be positively correlated. For example, GDP per Capita & Healthy Life Expectancy, suggesting that countries with higher economic indicators often also have better health outcomes; GDP per Capita & HDI (Human Development Index) shows a strong positive correlation between economic performance and human development outcomes. Also, Education Indicators & Economic Indicators reflects the common observation that more economically developed countries tend to invest more in education, leading to higher levels of human capital.
# Other features may show little or no linear association, for example, the generosity variable usually shows a weaker correlation with economic indicators; total population tends not to be directly related to development indicators or happiness scores, implying that their effect on the target might be less direct or perhaps non-linear.
#
# Associations with the Target Variable:
#
# Box plots comparing numerical features across different target categories reveal that certain features exhibit noticeable differences among groups. For instance, one might observe that countries classified as “Very High” in happiness tend to have higher social support or GDP per capita values compared to those in lower categories.
# For categorical features (such as region or country names), the distribution plots suggest some groups are more frequently associated with specific target categories, hinting at underlying regional patterns.
#
# Outlier Analysis:
#
# The IQR method quantitatively confirms the presence of outliers, with some features having a significant number of observations beyond the typical range.
#
# ### General comments
# Handling Outliers:
#
# Investigate Extreme Values: Examine outliers to determine whether they are due to data entry errors, measurement issues, or genuine variability.
# Data Cleaning or Transformation: Depending on their nature, consider removing, capping, or transforming outliers (e.g., using log or square root transformations) to mitigate their influence on model performance.
# Robust Modeling: Alternatively, employ robust algorithms that are less sensitive to outliers if removal is not feasible.
#
# Feature Engineering and Selection:
#
# Dealing with Multicollinearity: High correlations between some numerical features suggest the potential for multicollinearity. Consider combining these features or selecting a subset to improve model interpretability and performance.
# Transformation of Skewed Data: For features with noticeable skewness, applying appropriate transformations may help in achieving a more normal distribution, which can benefit many modeling techniques.
# Categorical Variables: Evaluate the importance of categorical features and consider encoding them properly (e.g., one-hot encoding) for subsequent modeling.
#
# Further Analysis:
#
# Non-linear Relationships: If some features show non-linear associations with the target, consider exploring non-linear transformations or advanced models (e.g., tree-based models) that can capture these relationships.
# Domain Knowledge: Incorporate domain expertise to understand if the observed patterns make sense and to determine the best approach for feature selection and preprocessing.
#
# Modeling Considerations:
#
# Data Scaling: Given the differences in the range of numerical features, applying standardization or normalization could be beneficial.
# Cross-validation: Ensure that any preprocessing steps (especially those handling outliers) are integrated with the modeling pipeline and validated properly using cross-validation techniques.

# %% [markdown]
# ## 2. Feature Engineering

# %% [markdown]
# Apply log transformations to normalize skewed data and improve model stability (If any).

# %%
# Your code here:
import numpy as np
import pandas as pd
from scipy.stats import skew

numeric_features = X_train.select_dtypes(include=[np.number]).columns

skewed_feats = []
for col in numeric_features:
    skew_val = skew(X_train[col].dropna())
    if abs(skew_val) > 1:
        skewed_feats.append(col)

print("Skewed Features:", skewed_feats)
# Out:
# Skewed Features: ['perceptions_of_corruption', 'population', 'population_below_poverty_line', 'gni']

# %%
# List of skewed features identified
skewed_feats = ['perceptions_of_corruption', 'population', 'population_below_poverty_line', 'gni']

# apply log transformation
for feat in skewed_feats:
    min_val = X_train[feat].min()
    if min_val <= 0:
        shift = abs(min_val) + 1
    else:
        shift = 0
    X_train[feat] = np.log1p(X_train[feat] + shift)
    X_test[feat] = np.log1p(X_test[feat] + shift)

    print(f"{feat}: shift = {shift} applied. New skewness (train) = {np.round(np.abs(np.log1p(X_train[feat]).skew()), 2)}")
# Out:
# perceptions_of_corruption: shift = 1.0 applied. New skewness (train) = 1.42
# population: shift = 0 applied. New skewness (train) = 0.15
# population_below_poverty_line: shift = 0 applied. New skewness (train) = 0.97
# gni: shift = 0 applied. New skewness (train) = 0.58

# %% [markdown]
# Create at least one interaction feature to capture relationship between existing variables, enhancing predictive power.

# %%
# Your code here:
# Interact the product of GDP per capita and social support
whr_df['gdp_social'] = whr_df['gdp_per_capita'] * whr_df['social_support']

X = whr_df.drop(columns=['happiness_score', 'happiness_category'])
y = whr_df['happiness_category']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

print(X_train[['gdp_per_capita', 'social_support', 'gdp_social']].head())
# Out:
#      gdp_per_capita  social_support  gdp_social
# 126           0.632           0.779    0.492328
# 102           1.099           0.764    0.839636
# 60            1.379           1.494    2.060226
# 79            0.972           1.248    1.213056
# 91            1.358           1.354    1.838732

# %% [markdown]
# ## 3.   Preprocess data using Sklearn Column Transformer/ Write and Save Preprocessor function

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# Create the preprocessing pipelines for both numeric and categorical data.

numeric_features = X_train.select_dtypes(include=['int64', 'float64'])
numeric_features=numeric_features.columns.tolist()

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')), ## Is (strategy='constant', fill_value=0) good enough?(NO, for many of these features—such as life expectancy, years of schooling, and gni—a value of 0 is not realistic and could distort the distribution.)
    ('scaler', StandardScaler())]) # You will need to describe why this is being done in the next cell

categorical_features = ['region']

#Replacing missing values with Modal value and then one hot encoding.
categorical_transformer = Pipeline(steps=[
    ('imputer',  SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# final preprocessor object set up with ColumnTransformer
preprocessor = ColumnTransformer(transformers=[('num', numeric_transformer, numeric_features),('cat', categorical_transformer, categorical_features)])

#Fit your preprocessor object
preprocess=preprocessor.fit(X_train)

# %% [markdown]
# Describe step-by-step what we are doing above, and why? You are free to change how values are imputed. What change did you make if any, and why?

# %% [markdown]
# We import various classes and functions from scikit-learn (such as StandardScaler, OneHotEncoder, ColumnTransformer, Pipeline, and SimpleImputer) that will be used to build preprocessing pipelines.
# We select all columns from X_train that have numeric data types (either integers or floats) and convert the resulting column index to a list. This gives us a list of numeric features that we need to preprocess (impute missing values and scale) separately from categorical features.
# Then We create a pipeline for numeric features which contains: Imputation(Missing values are replaced using SimpleImputer with a constant value of 0.) and Scaling(Standardization of the features is performed using StandardScaler, which scales data to have a mean of 0 and a standard deviation of 1.)
#
# Change:
# There's no 'sub_region' column in X_train data thus I delete it from categorical_features
# Instead of using strategy='constant', fill_value=0, it is better to use a more appropriate strategy like strategy='median' (or 'mean')

# %%
# Write function to transform data with preprocessor

def preprocessor(data):
    data.drop(['country', 'region'], axis=1)
    preprocessed_data=preprocess.transform(data)
    return preprocessed_data

# %% [markdown]
# What are the differences between the "preprocessor" object, the "preprocess" object, the "preprocessor" function,  and the "preprocessed_data" that is returned finally?

# %% [markdown]
# The "preprocessor" object is the ColumnTransformer you create, which defines the transformation pipelines for different feature types (numeric and categorical). It specifies what operations to perform (imputation, scaling, encoding) on which columns, but it hasn’t been fitted to data yet.
#
# The "preprocess" object is the fitted version of the "preprocessor" object. After calling preprocessor.fit(X_train), it learns the necessary parameters (e.g., medians, means, scales, categories) from the training data. You then use this fitted object to transform new data consistently.
#
# The "preprocessor" function is a user-defined function (in your case, named preprocessor or later renamed to something like transform_data) that uses the fitted "preprocess" object to transform a given dataset. It may also include additional steps like dropping specific columns before applying the transformation.
#
# The "preprocessed_data" is the final output that is returned by your "preprocessor" function. It is the transformed version of the input data, where all the specified preprocessing steps (imputation, scaling, encoding) have been applied.

# %%
# check shape of X data after preprocessing it using our new function
preprocessor(X_train).shape
# Out:
# (95, 17)

# %% [markdown]
# ## 4. Fit model on preprocessed data and save preprocessor function and model

# %%
from sklearn.ensemble import RandomForestClassifier

X_train_transformed = preprocessor(X_train)
X_test_transformed = preprocessor(X_test)

y_train_labels = y_train.astype('category').cat.codes
y_test_labels = y_test.astype('category').cat.codes

# Define a Random Forest Model here, fit it, and score it
model = RandomForestClassifier(random_state=40)
model.fit(X_train_transformed, y_train_labels)
score = model.score(X_test_transformed, y_test_labels)

print("Random Forest model score:", score)
# Your cell should have a score between 0-1 as output
# Out:
# Random Forest model score: 0.5714285714285714

# %% [markdown]
# ## 5. Generate predictions from X_test data and compare it with true labels in Y_test

# %%
#-- Generate predicted values (Model 1)
prediction_labels = model.predict(preprocessor(X_test))

## Write code to show model performance by comparing prediction_labels with true labels
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

accuracy = accuracy_score(y_test_labels, prediction_labels)
print("Accuracy:", accuracy)

print("Classification Report:")
print(classification_report(y_test_labels, prediction_labels))

# Confusion matrix
print("Confusion Matrix:")
display(confusion_matrix(y_test_labels, prediction_labels))
# Out:
# Accuracy: 0.5714285714285714
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67         9
#            1       0.50      0.38      0.43         8
#            2       0.50      0.75      0.60         8
#            3       0.38      0.38      0.38         8
#            4       0.86      0.67      0.75         9
#
#     accuracy                           0.57        42
#    macro avg       0.58      0.57      0.56        42
# weighted avg       0.59      0.57      0.57        42
#
# Confusion Matrix:
# array([[6, 3, 0, 0, 0],
#        [3, 3, 2, 0, 0],
#        [0, 0, 6, 2, 0],
#        [0, 0, 4, 3, 1],
#        [0, 0, 0, 3, 6]])

# %% [markdown]
# ## 6. Repeat the process with different parameters to improve the accuracy

# %%
from sklearn.ensemble import RandomForestClassifier

model_2 = RandomForestClassifier(
    random_state=40,
    n_estimators=600,
    max_depth=10,
    min_samples_split=4,
    min_samples_leaf=2,
    max_features='sqrt'
)

X_train_transformed = preprocessor(X_train)
X_test_transformed = preprocessor(X_test)

model_2.fit(X_train_transformed, y_train_labels)

score2 = model_2.score(X_test_transformed, y_test_labels)
print("Improved Random Forest model score:", score2)
# Out:
# Improved Random Forest model score: 0.6190476190476191

# %% [markdown]
#  What changes did you make, what do the parameters you changed control, and why does it improve performance?

# %% [markdown]
#  Increasing the number of trees (n_estimators) reduces the model’s variance, leading to more stable and reliable predictions.
#  Setting a maximum depth=10 and increasing the minimum number of samples required to split nodes=4 or form leaves=2, I constrain each tree’s complexity. This helps prevent the model from memorizing noise in the training data, thereby improving generalization on unseen data.
#  Using 'sqrt' for max_features helps ensure that individual trees are diverse, which is beneficial in ensemble methods like Random Forest.

# %%
#Evaluate Model 2:

#-- Generate predicted y values (Model 2)
prediction_labels = model_2.predict(X_test_transformed)

## Write code to show model performance by comparing prediction_labels with true labels
accuracy = accuracy_score(y_test_labels, prediction_labels)
print("Model 2 Accuracy:", accuracy)

print("Classification Report:")
print(classification_report(y_test_labels, prediction_labels))

print("Confusion Matrix:")
print(confusion_matrix(y_test_labels, prediction_labels))
# Out:
# Model 2 Accuracy: 0.6190476190476191
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.67      0.71         9
#            1       0.50      0.50      0.50         8
#            2       0.50      0.75      0.60         8
#            3       0.57      0.50      0.53         8
#            4       0.86      0.67      0.75         9
#
#     accuracy                           0.62        42
#    macro avg       0.64      0.62      0.62        42
# weighted avg       0.64      0.62      0.62        42
#
# Confusion Matrix:
# [[6 3 0 0 0]
#  [2 4 2 0 0]
#  [0 1 6 1 0]
#  [0 0 3 4 1]
#  [0 0 1 2 6]]

# %% [markdown]
# Do you think it is worth making more changes to the parameters? Should we keep trying random values and see what works better? What is an alternative to doing this manually?

# %% [markdown]
# NO, manually trying random values is inefficient and may not systematically lead to the best solution. An alternative is to use automated hyperparameter tuning methods such as GridSearchCV or RandomizedSearchCV, which allow you to define a parameter search space and systematically evaluate many combinations using cross-validation. More advanced techniques like Bayesian optimization (e.g., using libraries like Hyperopt or scikit-optimize) can also help efficiently explore the parameter space.

# %%
# Submit a third model using GridSearchCV

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
import numpy as np
param_grid = {
    'n_estimators': np.arange(100, 501, 100),
    'max_depth': [None, 5, 10, 15, 20],
    'min_samples_split': [2, 3, 4, 5],
    'min_samples_leaf': [1, 2, 3, 4],
    'max_features': ['sqrt', 'log2', None]
}

# Create a GridSearchCV object with RandomForestClassifier as the estimator
gridmodel = GridSearchCV(
    estimator=RandomForestClassifier(random_state=40),
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

X_train_transformed = preprocess.transform(X_train)
y_train_labels = y_train.astype('category').cat.codes

gridmodel.fit(X_train_transformed, y_train_labels)

print("best mean cross-validation score: {:.3f}".format(gridmodel.best_score_))
print("best parameters: {}".format(gridmodel.best_params_))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-dc2a8c453e74> in <cell line: 0>()
#      26
#      27 # Fit the grid search on the training data
# ---> 28 gridmodel.fit(X_train_transformed, y_train_labels)
#      29
#      30 # Extract and print the best cross-validation score and the corresponding parameters
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, **params)
#    1022                 return results
#    1023
# -> 1024             self._run_search(evaluate_candidates)
#    1025
#    1026             # multimetric is determined here because in the case of a callable
#
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1569     def _run_search(self, evaluate_candidates):
#    1570         """Search all candidates in param_grid"""
# -> 1571         evaluate_candidates(ParameterGrid(self.param_grid))
#    1572
#    1573
#
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     968                     )
#     969
# --> 970                 out = parallel(
#     971                     delayed(_fit_and_score)(
#     972                         clone(base_estimator),
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      75             for delayed_func, args, kwargs in iterable
#      76         )
# ---> 77         return super().__call__(iterable_with_config)
#      78
#      79
#
# /usr/local/lib/python3.11/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    2005         next(output)
#    2006
# -> 2007         return output if self.return_generator else list(output)
#    2008
#    2009     def __repr__(self):
#
# /usr/local/lib/python3.11/dist-packages/joblib/parallel.py in _get_outputs(self, iterator, pre_dispatch)
#    1648
#    1649             with self._backend.retrieval_context():
# -> 1650                 yield from self._retrieve()
#    1651
#    1652         except GeneratorExit:
#
# /usr/local/lib/python3.11/dist-packages/joblib/parallel.py in _retrieve(self)
#    1760                 (self._jobs[0].get_status(
#    1761                     timeout=self.timeout) == TASK_PENDING)):
# -> 1762                 time.sleep(0.01)
#    1763                 continue
#    1764
#
# KeyboardInterrupt:

# %%
#Submit Model 3:

# Generate predictions using the best estimator from our GridSearchCV (Model 3)
prediction_labels = gridmodel.predict(X_test_transformed)

# Evaluate the model's performance by comparing the predicted labels with the true labels.
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

accuracy = accuracy_score(y_test_labels, prediction_labels)
print("Model 3 Accuracy:", accuracy)

print("Classification Report:")
print(classification_report(y_test_labels, prediction_labels))

print("Confusion Matrix:")
print(confusion_matrix(y_test_labels, prediction_labels))
# Out:
# Model 3 Accuracy: 0.5714285714285714
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.50      0.67      0.57         9
#            1       0.20      0.12      0.15         8
#            2       0.46      0.75      0.57         8
#            3       1.00      0.50      0.67         8
#            4       0.88      0.78      0.82         9
#
#     accuracy                           0.57        42
#    macro avg       0.61      0.56      0.56        42
# weighted avg       0.61      0.57      0.56        42
#
# Confusion Matrix:
# [[6 3 0 0 0]
#  [5 1 2 0 0]
#  [1 1 6 0 0]
#  [0 0 3 4 1]
#  [0 0 2 0 7]]

# %%
# Here are several classic ML architectures you can consider choosing from to experiment with next:
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier

from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

model = SVC(random_state=40, kernel='rbf', C=1.0, gamma='scale')

X_train_transformed = preprocessor(X_train)
X_test_transformed = preprocessor(X_test)

y_train_labels = y_train.astype('category').cat.codes
y_test_labels = y_test.astype('category').cat.codes

model.fit(X_train_transformed, y_train_labels)


prediction_labels = model.predict(X_test_transformed)

accuracy = accuracy_score(y_test_labels, prediction_labels)
print("SVC Model Accuracy:", accuracy)

print("Classification Report:")
print(classification_report(y_test_labels, prediction_labels))

print("Confusion Matrix:")
print(confusion_matrix(y_test_labels, prediction_labels))
# Out:
# SVC Model Accuracy: 0.5
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.56      0.56      0.56         9
#            1       0.38      0.38      0.38         8
#            2       0.46      0.75      0.57         8
#            3       0.29      0.25      0.27         8
#            4       1.00      0.56      0.71         9
#
#     accuracy                           0.50        42
#    macro avg       0.54      0.50      0.50        42
# weighted avg       0.55      0.50      0.50        42
#
# Confusion Matrix:
# [[5 4 0 0 0]
#  [4 3 1 0 0]
#  [0 1 6 1 0]
#  [0 0 6 2 0]
#  [0 0 0 4 5]]

# %% [markdown]
# Describe what were the parameters you defined in GradientBoostingClassifier, and/or BaggingClassifier, and/or KNNs, and/or SVC? What worked and why?

# %% [markdown]
# **random_state=40:** This parameter ensures that any randomness in the algorithm (such as data shuffling or random selection during optimization) is consistent across runs, thereby making the results reproducible.
#
#
# **kernel='rbf':**
# The RBF (Radial Basis Function) kernel is used because it can capture complex non-linear relationships in the data. Many datasets have decision boundaries that are not linear, and the RBF kernel helps map the data into a higher-dimensional space where a linear separation might be possible.
#
#
# **C=1.0:** The C parameter is a regularization term that balances the trade-off between achieving a low training error and a low testing error (i.e., model complexity). A higher C value means the model will penalize misclassifications more, potentially leading to overfitting, while a lower C value allows for a softer margin that can improve generalization. Setting C to 1.0 is a common default that often provides a good balance between these factors.
#
#
# **gamma='scale':** The gamma parameter controls the influence of individual training samples on the decision boundary. When set to 'scale', gamma is automatically computed as 1 / (n_features * X.var()), which adapts to the data's characteristics. This auto-scaling often yields better results than manually setting gamma, as it adjusts based on the data’s variance and the number of features.

# %% [markdown]
# ## 7. Basic Deep Learning

# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.11/dist-packages (3.8.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from keras) (3.12.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras) (0.14.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.11/dist-packages (from keras) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from keras) (24.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from optree->keras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.25.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %%
# Now experiment with deep learning models:

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical


feature_count = preprocessor(X_train).shape[1]

keras_model = Sequential([
    Dense(128, input_dim=feature_count, activation='relu'),
    Dense(64, activation='relu'),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(5, activation='softmax')
])

#Use Softmax activation in last layer. How many neurons should there be in the last layer?
# 5 classes -> 5 neurons


# Compile model
keras_model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

y_train_onehot = to_categorical(y_train.astype('category').cat.codes)
# Fitting the NN to the Training set
keras_model.fit(preprocessor(X_train), y_train_onehot, ## Note that keras models require a one-hot-encoded y_train object
               batch_size = 20,
               epochs = 300, validation_split=0.25)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 165ms/step - accuracy: 0.2462 - loss: 1.6290 - val_accuracy: 0.2083 - val_loss: 1.6176
# Epoch 2/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.2462 - loss: 1.6118 - val_accuracy: 0.2083 - val_loss: 1.6150
# Epoch 3/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.2162 - loss: 1.6230 - val_accuracy: 0.2083 - val_loss: 1.6129
# Epoch 4/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.1978 - loss: 1.6127 - val_accuracy: 0.2083 - val_loss: 1.6104
# Epoch 5/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.1978 - loss: 1.6110 - val_accuracy: 0.2083 - val_loss: 1.6087
# Epoch 6/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.1612 - loss: 1.6146 - val_accuracy: 0.2083 - val_loss: 1.6067
# Epoch 7/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.2285 - loss: 1.5987 - val_accuracy: 0.2083 - val_loss: 1.6048
# Epoch 8/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.2278 - loss: 1.5840 - val_accuracy: 0.2083 - val_loss: 1.6026
# Epoch 9/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.2051 - loss: 1.5853 - val_accuracy: 0.2083 - val_loss: 1.6004
# Epoch 10/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.2104 - loss: 1.5820 - val_accuracy: 0.2083 - val_loss: 1.5984
# Epoch 11/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2697 - loss: 1.5694 - val_accuracy: 0.2083 - val_loss: 1.5965
# Epoch 12/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.3050 - loss: 1.5677 - val_accuracy: 0.2083 - val_loss: 1.5946
# Epoch 13/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - accuracy: 0.3783 - loss: 1.5579 - val_accuracy: 0.1667 - val_loss: 1.5927
# Epoch 14/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.2973 - loss: 1.5621 - val_accuracy: 0.1667 - val_loss: 1.5908
# Epoch 15/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.3285 - loss: 1.5578 - val_accuracy: 0.1667 - val_loss: 1.5890
# Epoch 16/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.3481 - loss: 1.5519 - val_accuracy: 0.1667 - val_loss: 1.5868
# Epoch 17/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.3711 - loss: 1.5499 - val_accuracy: 0.1667 - val_loss: 1.5847
# Epoch 18/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.3838 - loss: 1.5397 - val_accuracy: 0.1667 - val_loss: 1.5823
# Epoch 19/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.3544 - loss: 1.5310 - val_accuracy: 0.1667 - val_loss: 1.5798
# Epoch 20/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3911 - loss: 1.5314 - val_accuracy: 0.1667 - val_loss: 1.5778
# Epoch 21/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3927 - loss: 1.5267 - val_accuracy: 0.1250 - val_loss: 1.5759
# Epoch 22/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4144 - loss: 1.5170 - val_accuracy: 0.1250 - val_loss: 1.5737
# Epoch 23/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.3927 - loss: 1.5135 - val_accuracy: 0.1667 - val_loss: 1.5710
# Epoch 24/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.3571 - loss: 1.5010 - val_accuracy: 0.1667 - val_loss: 1.5685
# Epoch 25/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.4600 - loss: 1.5006 - val_accuracy: 0.1250 - val_loss: 1.5662
# Epoch 26/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4867 - loss: 1.4757 - val_accuracy: 0.1667 - val_loss: 1.5635
# Epoch 27/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.3950 - loss: 1.4967 - val_accuracy: 0.2083 - val_loss: 1.5612
# Epoch 28/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.3784 - loss: 1.4913 - val_accuracy: 0.2500 - val_loss: 1.5587
# Epoch 29/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.3784 - loss: 1.4849 - val_accuracy: 0.2500 - val_loss: 1.5563
# Epoch 30/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.3794 - loss: 1.4706 - val_accuracy: 0.2500 - val_loss: 1.5536
# Epoch 31/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.3811 - loss: 1.4615 - val_accuracy: 0.2500 - val_loss: 1.5508
# Epoch 32/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.3761 - loss: 1.4533 - val_accuracy: 0.2500 - val_loss: 1.5478
# Epoch 33/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4077 - loss: 1.4304 - val_accuracy: 0.2500 - val_loss: 1.5444
# Epoch 34/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.3977 - loss: 1.4381 - val_accuracy: 0.2500 - val_loss: 1.5412
# Epoch 35/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.3644 - loss: 1.4475 - val_accuracy: 0.2917 - val_loss: 1.5384
# Epoch 36/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4500 - loss: 1.4264 - val_accuracy: 0.2917 - val_loss: 1.5353
# Epoch 37/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4134 - loss: 1.4269 - val_accuracy: 0.2917 - val_loss: 1.5320
# Epoch 38/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.3771 - loss: 1.4138 - val_accuracy: 0.2917 - val_loss: 1.5291
# Epoch 39/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.4523 - loss: 1.3772 - val_accuracy: 0.2917 - val_loss: 1.5251
# Epoch 40/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4646 - loss: 1.3721 - val_accuracy: 0.2917 - val_loss: 1.5213
# Epoch 41/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4776 - loss: 1.3636 - val_accuracy: 0.2917 - val_loss: 1.5172
# Epoch 42/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.4809 - loss: 1.3639 - val_accuracy: 0.2917 - val_loss: 1.5133
# Epoch 43/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4759 - loss: 1.3754 - val_accuracy: 0.2917 - val_loss: 1.5086
# Epoch 44/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5115 - loss: 1.3319 - val_accuracy: 0.2917 - val_loss: 1.5048
# Epoch 45/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.4338 - loss: 1.3828 - val_accuracy: 0.2917 - val_loss: 1.5012
# Epoch 46/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5088 - loss: 1.3376 - val_accuracy: 0.2917 - val_loss: 1.4970
# Epoch 47/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5401 - loss: 1.3230 - val_accuracy: 0.2917 - val_loss: 1.4931
# Epoch 48/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4885 - loss: 1.3413 - val_accuracy: 0.2500 - val_loss: 1.4900
# Epoch 49/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.4851 - loss: 1.3148 - val_accuracy: 0.2500 - val_loss: 1.4859
# Epoch 50/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5910 - loss: 1.3064 - val_accuracy: 0.2500 - val_loss: 1.4808
# Epoch 51/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5843 - loss: 1.2793 - val_accuracy: 0.2917 - val_loss: 1.4756
# Epoch 52/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6043 - loss: 1.2341 - val_accuracy: 0.2917 - val_loss: 1.4711
# Epoch 53/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5743 - loss: 1.2677 - val_accuracy: 0.2917 - val_loss: 1.4670
# Epoch 54/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6033 - loss: 1.2421 - val_accuracy: 0.2917 - val_loss: 1.4623
# Epoch 55/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6083 - loss: 1.2286 - val_accuracy: 0.3750 - val_loss: 1.4570
# Epoch 56/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5756 - loss: 1.2558 - val_accuracy: 0.3750 - val_loss: 1.4524
# Epoch 57/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5966 - loss: 1.1962 - val_accuracy: 0.3333 - val_loss: 1.4473
# Epoch 58/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5824 - loss: 1.1992 - val_accuracy: 0.3333 - val_loss: 1.4429
# Epoch 59/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4985 - loss: 1.2161 - val_accuracy: 0.3333 - val_loss: 1.4376
# Epoch 60/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5291 - loss: 1.2094 - val_accuracy: 0.3333 - val_loss: 1.4325
# Epoch 61/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5395 - loss: 1.1621 - val_accuracy: 0.3333 - val_loss: 1.4281
# Epoch 62/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5062 - loss: 1.1793 - val_accuracy: 0.3333 - val_loss: 1.4232
# Epoch 63/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5462 - loss: 1.1532 - val_accuracy: 0.2917 - val_loss: 1.4181
# Epoch 64/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5378 - loss: 1.1590 - val_accuracy: 0.2917 - val_loss: 1.4136
# Epoch 65/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5062 - loss: 1.1506 - val_accuracy: 0.2917 - val_loss: 1.4099
# Epoch 66/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5491 - loss: 1.1289 - val_accuracy: 0.2500 - val_loss: 1.4040
# Epoch 67/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5185 - loss: 1.1646 - val_accuracy: 0.2500 - val_loss: 1.4013
# Epoch 68/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5012 - loss: 1.1526 - val_accuracy: 0.2500 - val_loss: 1.3970
# Epoch 69/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5358 - loss: 1.1032 - val_accuracy: 0.2500 - val_loss: 1.3927
# Epoch 70/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5301 - loss: 1.0559 - val_accuracy: 0.2500 - val_loss: 1.3871
# Epoch 71/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5264 - loss: 1.0962 - val_accuracy: 0.2500 - val_loss: 1.3824
# Epoch 72/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5741 - loss: 1.0420 - val_accuracy: 0.2500 - val_loss: 1.3769
# Epoch 73/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5141 - loss: 1.0991 - val_accuracy: 0.2500 - val_loss: 1.3731
# Epoch 74/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5108 - loss: 1.0538 - val_accuracy: 0.2917 - val_loss: 1.3670
# Epoch 75/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5697 - loss: 1.0675 - val_accuracy: 0.2500 - val_loss: 1.3636
# Epoch 76/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5804 - loss: 1.0135 - val_accuracy: 0.2917 - val_loss: 1.3560
# Epoch 77/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5231 - loss: 1.0450 - val_accuracy: 0.2917 - val_loss: 1.3517
# Epoch 78/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5081 - loss: 1.0211 - val_accuracy: 0.2500 - val_loss: 1.3474
# Epoch 79/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5720 - loss: 0.9843 - val_accuracy: 0.3333 - val_loss: 1.3429
# Epoch 80/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5347 - loss: 0.9912 - val_accuracy: 0.3333 - val_loss: 1.3387
# Epoch 81/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5214 - loss: 1.0052 - val_accuracy: 0.3333 - val_loss: 1.3335
# Epoch 82/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5547 - loss: 0.9871 - val_accuracy: 0.3333 - val_loss: 1.3301
# Epoch 83/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6037 - loss: 0.9379 - val_accuracy: 0.3333 - val_loss: 1.3229
# Epoch 84/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6037 - loss: 0.9627 - val_accuracy: 0.3333 - val_loss: 1.3177
# Epoch 85/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5387 - loss: 1.0082 - val_accuracy: 0.3333 - val_loss: 1.3140
# Epoch 86/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.5854 - loss: 0.9391 - val_accuracy: 0.3333 - val_loss: 1.3093
# Epoch 87/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5304 - loss: 0.9908 - val_accuracy: 0.3333 - val_loss: 1.3050
# Epoch 88/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5970 - loss: 0.9279 - val_accuracy: 0.3333 - val_loss: 1.3015
# Epoch 89/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6196 - loss: 0.9737 - val_accuracy: 0.3333 - val_loss: 1.2961
# Epoch 90/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6093 - loss: 0.9330 - val_accuracy: 0.3333 - val_loss: 1.2912
# Epoch 91/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6323 - loss: 0.9424 - val_accuracy: 0.3333 - val_loss: 1.2910
# Epoch 92/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6162 - loss: 0.9157 - val_accuracy: 0.3333 - val_loss: 1.2862
# Epoch 93/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6769 - loss: 0.8549 - val_accuracy: 0.3333 - val_loss: 1.2813
# Epoch 94/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6196 - loss: 0.9456 - val_accuracy: 0.3333 - val_loss: 1.2767
# Epoch 95/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6229 - loss: 0.8697 - val_accuracy: 0.3333 - val_loss: 1.2712
# Epoch 96/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6352 - loss: 0.9306 - val_accuracy: 0.3333 - val_loss: 1.2701
# Epoch 97/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6608 - loss: 0.8824 - val_accuracy: 0.3333 - val_loss: 1.2650
# Epoch 98/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7308 - loss: 0.8673 - val_accuracy: 0.3750 - val_loss: 1.2636
# Epoch 99/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6492 - loss: 0.9119 - val_accuracy: 0.3750 - val_loss: 1.2580
# Epoch 100/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6615 - loss: 0.8969 - val_accuracy: 0.3750 - val_loss: 1.2554
# Epoch 101/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6498 - loss: 0.9276 - val_accuracy: 0.3750 - val_loss: 1.2570
# Epoch 102/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6215 - loss: 0.9174 - val_accuracy: 0.3750 - val_loss: 1.2534
# Epoch 103/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6708 - loss: 0.8296 - val_accuracy: 0.3750 - val_loss: 1.2498
# Epoch 104/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6865 - loss: 0.8603 - val_accuracy: 0.3750 - val_loss: 1.2474
# Epoch 105/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6625 - loss: 0.8548 - val_accuracy: 0.3333 - val_loss: 1.2449
# Epoch 106/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6725 - loss: 0.8384 - val_accuracy: 0.3750 - val_loss: 1.2379
# Epoch 107/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6504 - loss: 0.8909 - val_accuracy: 0.3333 - val_loss: 1.2406
# Epoch 108/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6315 - loss: 0.8828 - val_accuracy: 0.3750 - val_loss: 1.2356
# Epoch 109/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6558 - loss: 0.8494 - val_accuracy: 0.3750 - val_loss: 1.2277
# Epoch 110/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6254 - loss: 0.8981 - val_accuracy: 0.3750 - val_loss: 1.2279
# Epoch 111/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6538 - loss: 0.9016 - val_accuracy: 0.3750 - val_loss: 1.2272
# Epoch 112/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6921 - loss: 0.8511 - val_accuracy: 0.3333 - val_loss: 1.2263
# Epoch 113/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6444 - loss: 0.8247 - val_accuracy: 0.3333 - val_loss: 1.2235
# Epoch 114/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6865 - loss: 0.8295 - val_accuracy: 0.3333 - val_loss: 1.2184
# Epoch 115/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6771 - loss: 0.8525 - val_accuracy: 0.2917 - val_loss: 1.2166
# Epoch 116/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6915 - loss: 0.7741 - val_accuracy: 0.2917 - val_loss: 1.2162
# Epoch 117/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6648 - loss: 0.8356 - val_accuracy: 0.3333 - val_loss: 1.2155
# Epoch 118/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7411 - loss: 0.7775 - val_accuracy: 0.3333 - val_loss: 1.2130
# Epoch 119/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6738 - loss: 0.8085 - val_accuracy: 0.3333 - val_loss: 1.2105
# Epoch 120/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6265 - loss: 0.8676 - val_accuracy: 0.3333 - val_loss: 1.2048
# Epoch 121/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6875 - loss: 0.7774 - val_accuracy: 0.2917 - val_loss: 1.2040
# Epoch 122/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6438 - loss: 0.8340 - val_accuracy: 0.3333 - val_loss: 1.2084
# Epoch 123/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6748 - loss: 0.7815 - val_accuracy: 0.3333 - val_loss: 1.2055
# Epoch 124/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7181 - loss: 0.8222 - val_accuracy: 0.2917 - val_loss: 1.2033
# Epoch 125/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6888 - loss: 0.7744 - val_accuracy: 0.2917 - val_loss: 1.1976
# Epoch 126/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6638 - loss: 0.7915 - val_accuracy: 0.3333 - val_loss: 1.1935
# Epoch 127/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6365 - loss: 0.8380 - val_accuracy: 0.2917 - val_loss: 1.1967
# Epoch 128/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6798 - loss: 0.7335 - val_accuracy: 0.2917 - val_loss: 1.1951
# Epoch 129/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6681 - loss: 0.8131 - val_accuracy: 0.2917 - val_loss: 1.1901
# Epoch 130/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6698 - loss: 0.7533 - val_accuracy: 0.2917 - val_loss: 1.1959
# Epoch 131/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6821 - loss: 0.7777 - val_accuracy: 0.2917 - val_loss: 1.1892
# Epoch 132/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6788 - loss: 0.7704 - val_accuracy: 0.2917 - val_loss: 1.1852
# Epoch 133/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6788 - loss: 0.7761 - val_accuracy: 0.2917 - val_loss: 1.1891
# Epoch 134/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6921 - loss: 0.7792 - val_accuracy: 0.2917 - val_loss: 1.1859
# Epoch 135/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6921 - loss: 0.7544 - val_accuracy: 0.3333 - val_loss: 1.1893
# Epoch 136/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6644 - loss: 0.7943 - val_accuracy: 0.2917 - val_loss: 1.1907
# Epoch 137/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6888 - loss: 0.7458 - val_accuracy: 0.3333 - val_loss: 1.1845
# Epoch 138/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6688 - loss: 0.7510 - val_accuracy: 0.3750 - val_loss: 1.1863
# Epoch 139/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7044 - loss: 0.7244 - val_accuracy: 0.3750 - val_loss: 1.1894
# Epoch 140/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6561 - loss: 0.7867 - val_accuracy: 0.3333 - val_loss: 1.1852
# Epoch 141/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7144 - loss: 0.7407 - val_accuracy: 0.3333 - val_loss: 1.1865
# Epoch 142/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6688 - loss: 0.7790 - val_accuracy: 0.3750 - val_loss: 1.1870
# Epoch 143/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7423 - loss: 0.7474 - val_accuracy: 0.3333 - val_loss: 1.1892
# Epoch 144/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6627 - loss: 0.7630 - val_accuracy: 0.3333 - val_loss: 1.1868
# Epoch 145/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6527 - loss: 0.7631 - val_accuracy: 0.3333 - val_loss: 1.1867
# Epoch 146/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6800 - loss: 0.7549 - val_accuracy: 0.2917 - val_loss: 1.1817
# Epoch 147/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7377 - loss: 0.7116 - val_accuracy: 0.3333 - val_loss: 1.1826
# Epoch 148/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6634 - loss: 0.7592 - val_accuracy: 0.3333 - val_loss: 1.1902
# Epoch 149/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6827 - loss: 0.7447 - val_accuracy: 0.3750 - val_loss: 1.1880
# Epoch 150/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7334 - loss: 0.7579 - val_accuracy: 0.3333 - val_loss: 1.1797
# Epoch 151/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7067 - loss: 0.7308 - val_accuracy: 0.3750 - val_loss: 1.1797
# Epoch 152/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7277 - loss: 0.7416 - val_accuracy: 0.3333 - val_loss: 1.1779
# Epoch 153/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7234 - loss: 0.7150 - val_accuracy: 0.3333 - val_loss: 1.1716
# Epoch 154/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7311 - loss: 0.7077 - val_accuracy: 0.2917 - val_loss: 1.1768
# Epoch 155/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7357 - loss: 0.7114 - val_accuracy: 0.2917 - val_loss: 1.1786
# Epoch 156/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7040 - loss: 0.7182 - val_accuracy: 0.3333 - val_loss: 1.1826
# Epoch 157/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6627 - loss: 0.7432 - val_accuracy: 0.3333 - val_loss: 1.1787
# Epoch 158/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6767 - loss: 0.7033 - val_accuracy: 0.3333 - val_loss: 1.1808
# Epoch 159/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7167 - loss: 0.7092 - val_accuracy: 0.3333 - val_loss: 1.1809
# Epoch 160/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7457 - loss: 0.6966 - val_accuracy: 0.3333 - val_loss: 1.1793
# Epoch 161/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6650 - loss: 0.7306 - val_accuracy: 0.3333 - val_loss: 1.1782
# Epoch 162/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6911 - loss: 0.7057 - val_accuracy: 0.3750 - val_loss: 1.1776
# Epoch 163/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7217 - loss: 0.6819 - val_accuracy: 0.3333 - val_loss: 1.1829
# Epoch 164/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7061 - loss: 0.6723 - val_accuracy: 0.3333 - val_loss: 1.1858
# Epoch 165/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6757 - loss: 0.7018 - val_accuracy: 0.3333 - val_loss: 1.1809
# Epoch 166/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7127 - loss: 0.6989 - val_accuracy: 0.3750 - val_loss: 1.1804
# Epoch 167/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7117 - loss: 0.6874 - val_accuracy: 0.3333 - val_loss: 1.1812
# Epoch 168/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7386 - loss: 0.6874 - val_accuracy: 0.3750 - val_loss: 1.1854
# Epoch 169/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7496 - loss: 0.6310 - val_accuracy: 0.3750 - val_loss: 1.1680
# Epoch 170/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6940 - loss: 0.6996 - val_accuracy: 0.3750 - val_loss: 1.1694
# Epoch 171/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7267 - loss: 0.6480 - val_accuracy: 0.3750 - val_loss: 1.1686
# Epoch 172/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7223 - loss: 0.6812 - val_accuracy: 0.3750 - val_loss: 1.1740
# Epoch 173/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6973 - loss: 0.6888 - val_accuracy: 0.3333 - val_loss: 1.1810
# Epoch 174/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7530 - loss: 0.6774 - val_accuracy: 0.3750 - val_loss: 1.1760
# Epoch 175/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7380 - loss: 0.6838 - val_accuracy: 0.3333 - val_loss: 1.1783
# Epoch 176/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7690 - loss: 0.6459 - val_accuracy: 0.3750 - val_loss: 1.1678
# Epoch 177/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6980 - loss: 0.6870 - val_accuracy: 0.3750 - val_loss: 1.1713
# Epoch 178/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7086 - loss: 0.6887 - val_accuracy: 0.3750 - val_loss: 1.1711
# Epoch 179/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7063 - loss: 0.6663 - val_accuracy: 0.3750 - val_loss: 1.1747
# Epoch 180/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6913 - loss: 0.6974 - val_accuracy: 0.3750 - val_loss: 1.1734
# Epoch 181/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7413 - loss: 0.6760 - val_accuracy: 0.3750 - val_loss: 1.1807
# Epoch 182/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7382 - loss: 0.6672 - val_accuracy: 0.3750 - val_loss: 1.1835
# Epoch 183/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7603 - loss: 0.6387 - val_accuracy: 0.3750 - val_loss: 1.1742
# Epoch 184/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7769 - loss: 0.6315 - val_accuracy: 0.3333 - val_loss: 1.1732
# Epoch 185/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7965 - loss: 0.6398 - val_accuracy: 0.3750 - val_loss: 1.1668
# Epoch 186/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7549 - loss: 0.6823 - val_accuracy: 0.3750 - val_loss: 1.1680
# Epoch 187/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7553 - loss: 0.6527 - val_accuracy: 0.3750 - val_loss: 1.1693
# Epoch 188/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7736 - loss: 0.6381 - val_accuracy: 0.3750 - val_loss: 1.1771
# Epoch 189/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7805 - loss: 0.6289 - val_accuracy: 0.4167 - val_loss: 1.1771
# Epoch 190/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7563 - loss: 0.6377 - val_accuracy: 0.3750 - val_loss: 1.1765
# Epoch 191/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7732 - loss: 0.6294 - val_accuracy: 0.3750 - val_loss: 1.1762
# Epoch 192/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7419 - loss: 0.6351 - val_accuracy: 0.3750 - val_loss: 1.1758
# Epoch 193/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7632 - loss: 0.6552 - val_accuracy: 0.4167 - val_loss: 1.1729
# Epoch 194/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7815 - loss: 0.6158 - val_accuracy: 0.4167 - val_loss: 1.1792
# Epoch 195/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7786 - loss: 0.6241 - val_accuracy: 0.4167 - val_loss: 1.1749
# Epoch 196/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7686 - loss: 0.6126 - val_accuracy: 0.4167 - val_loss: 1.1780
# Epoch 197/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7699 - loss: 0.5941 - val_accuracy: 0.4167 - val_loss: 1.1701
# Epoch 198/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7663 - loss: 0.6374 - val_accuracy: 0.4167 - val_loss: 1.1781
# Epoch 199/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7672 - loss: 0.6407 - val_accuracy: 0.4167 - val_loss: 1.1751
# Epoch 200/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7359 - loss: 0.6500 - val_accuracy: 0.3750 - val_loss: 1.1917
# Epoch 201/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7176 - loss: 0.6596 - val_accuracy: 0.4167 - val_loss: 1.1947
# Epoch 202/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7492 - loss: 0.6367 - val_accuracy: 0.3750 - val_loss: 1.1989
# Epoch 203/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8215 - loss: 0.5935 - val_accuracy: 0.3750 - val_loss: 1.1964
# Epoch 204/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7972 - loss: 0.5943 - val_accuracy: 0.4167 - val_loss: 1.1952
# Epoch 205/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7738 - loss: 0.5789 - val_accuracy: 0.4167 - val_loss: 1.1877
# Epoch 206/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8078 - loss: 0.6165 - val_accuracy: 0.3750 - val_loss: 1.2118
# Epoch 207/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8245 - loss: 0.5808 - val_accuracy: 0.3750 - val_loss: 1.2032
# Epoch 208/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6959 - loss: 0.6430 - val_accuracy: 0.4167 - val_loss: 1.2054
# Epoch 209/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7842 - loss: 0.5855 - val_accuracy: 0.4167 - val_loss: 1.2102
# Epoch 210/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7815 - loss: 0.5884 - val_accuracy: 0.4167 - val_loss: 1.2170
# Epoch 211/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8105 - loss: 0.5855 - val_accuracy: 0.4167 - val_loss: 1.2132
# Epoch 212/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7665 - loss: 0.6096 - val_accuracy: 0.4167 - val_loss: 1.2147
# Epoch 213/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7449 - loss: 0.6259 - val_accuracy: 0.4167 - val_loss: 1.2129
# Epoch 214/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7955 - loss: 0.5531 - val_accuracy: 0.4167 - val_loss: 1.2119
# Epoch 215/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8088 - loss: 0.5586 - val_accuracy: 0.4167 - val_loss: 1.2161
# Epoch 216/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7892 - loss: 0.5917 - val_accuracy: 0.4167 - val_loss: 1.2197
# Epoch 217/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7728 - loss: 0.5899 - val_accuracy: 0.4167 - val_loss: 1.2190
# Epoch 218/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8395 - loss: 0.5544 - val_accuracy: 0.4167 - val_loss: 1.2320
# Epoch 219/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8028 - loss: 0.5500 - val_accuracy: 0.4167 - val_loss: 1.2194
# Epoch 220/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8072 - loss: 0.5820 - val_accuracy: 0.4167 - val_loss: 1.2206
# Epoch 221/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7882 - loss: 0.5679 - val_accuracy: 0.4167 - val_loss: 1.2201
# Epoch 222/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7728 - loss: 0.5949 - val_accuracy: 0.4167 - val_loss: 1.2193
# Epoch 223/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8361 - loss: 0.5420 - val_accuracy: 0.3750 - val_loss: 1.2102
# Epoch 224/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8211 - loss: 0.5578 - val_accuracy: 0.4167 - val_loss: 1.2164
# Epoch 225/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8145 - loss: 0.5759 - val_accuracy: 0.4167 - val_loss: 1.2194
# Epoch 226/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8407 - loss: 0.5770 - val_accuracy: 0.3750 - val_loss: 1.2333
# Epoch 227/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8561 - loss: 0.5347 - val_accuracy: 0.4167 - val_loss: 1.2211
# Epoch 228/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8191 - loss: 0.5698 - val_accuracy: 0.4167 - val_loss: 1.2345
# Epoch 229/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8007 - loss: 0.5745 - val_accuracy: 0.4167 - val_loss: 1.2427
# Epoch 230/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8830 - loss: 0.5379 - val_accuracy: 0.4167 - val_loss: 1.2373
# Epoch 231/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7974 - loss: 0.5855 - val_accuracy: 0.4167 - val_loss: 1.2335
# Epoch 232/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8134 - loss: 0.5760 - val_accuracy: 0.4167 - val_loss: 1.2337
# Epoch 233/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7861 - loss: 0.5681 - val_accuracy: 0.4167 - val_loss: 1.2429
# Epoch 234/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8318 - loss: 0.5750 - val_accuracy: 0.4167 - val_loss: 1.2346
# Epoch 235/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8274 - loss: 0.5684 - val_accuracy: 0.4167 - val_loss: 1.2469
# Epoch 236/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8430 - loss: 0.5607 - val_accuracy: 0.4167 - val_loss: 1.2553
# Epoch 237/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8437 - loss: 0.5725 - val_accuracy: 0.3750 - val_loss: 1.2583
# Epoch 238/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8205 - loss: 0.5074 - val_accuracy: 0.3750 - val_loss: 1.2455
# Epoch 239/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8418 - loss: 0.5598 - val_accuracy: 0.4167 - val_loss: 1.2494
# Epoch 240/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8351 - loss: 0.5045 - val_accuracy: 0.4167 - val_loss: 1.2601
# Epoch 241/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8364 - loss: 0.5240 - val_accuracy: 0.4167 - val_loss: 1.2734
# Epoch 242/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8847 - loss: 0.5243 - val_accuracy: 0.4167 - val_loss: 1.2598
# Epoch 243/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8603 - loss: 0.5229 - val_accuracy: 0.4167 - val_loss: 1.2502
# Epoch 244/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8191 - loss: 0.5299 - val_accuracy: 0.4167 - val_loss: 1.2674
# Epoch 245/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8284 - loss: 0.5150 - val_accuracy: 0.4167 - val_loss: 1.2635
# Epoch 246/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8430 - loss: 0.5197 - val_accuracy: 0.4167 - val_loss: 1.2622
# Epoch 247/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8364 - loss: 0.5298 - val_accuracy: 0.4167 - val_loss: 1.2692
# Epoch 248/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8537 - loss: 0.5253 - val_accuracy: 0.4167 - val_loss: 1.2817
# Epoch 249/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8537 - loss: 0.5460 - val_accuracy: 0.4167 - val_loss: 1.2764
# Epoch 250/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8870 - loss: 0.4887 - val_accuracy: 0.4167 - val_loss: 1.2646
# Epoch 251/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8351 - loss: 0.4873 - val_accuracy: 0.4167 - val_loss: 1.2658
# Epoch 252/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8128 - loss: 0.5128 - val_accuracy: 0.3750 - val_loss: 1.2774
# Epoch 253/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8191 - loss: 0.5600 - val_accuracy: 0.3750 - val_loss: 1.2725
# Epoch 254/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - accuracy: 0.8441 - loss: 0.5107 - val_accuracy: 0.4167 - val_loss: 1.2635
# Epoch 255/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.8114 - loss: 0.5392 - val_accuracy: 0.4583 - val_loss: 1.2709
# Epoch 256/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - accuracy: 0.7907 - loss: 0.5590 - val_accuracy: 0.4167 - val_loss: 1.2724
# Epoch 257/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.8397 - loss: 0.5304 - val_accuracy: 0.4167 - val_loss: 1.2840
# Epoch 258/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8584 - loss: 0.4950 - val_accuracy: 0.4167 - val_loss: 1.2747
# Epoch 259/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8018 - loss: 0.5097 - val_accuracy: 0.4167 - val_loss: 1.2917
# Epoch 260/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8514 - loss: 0.5013 - val_accuracy: 0.4167 - val_loss: 1.2826
# Epoch 261/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8474 - loss: 0.4874 - val_accuracy: 0.4167 - val_loss: 1.2830
# Epoch 262/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8147 - loss: 0.5102 - val_accuracy: 0.4167 - val_loss: 1.2965
# Epoch 263/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8195 - loss: 0.4945 - val_accuracy: 0.3333 - val_loss: 1.3038
# Epoch 264/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8291 - loss: 0.4915 - val_accuracy: 0.4167 - val_loss: 1.2741
# Epoch 265/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7984 - loss: 0.5019 - val_accuracy: 0.4167 - val_loss: 1.2852
# Epoch 266/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8474 - loss: 0.4857 - val_accuracy: 0.4167 - val_loss: 1.2926
# Epoch 267/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8391 - loss: 0.4881 - val_accuracy: 0.3750 - val_loss: 1.3192
# Epoch 268/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8380 - loss: 0.4946 - val_accuracy: 0.4167 - val_loss: 1.3054
# Epoch 269/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.8524 - loss: 0.5076 - val_accuracy: 0.3750 - val_loss: 1.3141
# Epoch 270/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8547 - loss: 0.4824 - val_accuracy: 0.3750 - val_loss: 1.3252
# Epoch 271/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8357 - loss: 0.4618 - val_accuracy: 0.3750 - val_loss: 1.3391
# Epoch 272/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8503 - loss: 0.4872 - val_accuracy: 0.3750 - val_loss: 1.3374
# Epoch 273/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8587 - loss: 0.4823 - val_accuracy: 0.4167 - val_loss: 1.3307
# Epoch 274/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8487 - loss: 0.4595 - val_accuracy: 0.4167 - val_loss: 1.3269
# Epoch 275/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 0.8530 - loss: 0.4414 - val_accuracy: 0.4167 - val_loss: 1.3171
# Epoch 276/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8501 - loss: 0.4723 - val_accuracy: 0.4167 - val_loss: 1.3274
# Epoch 277/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8387 - loss: 0.4773 - val_accuracy: 0.4167 - val_loss: 1.3323
# Epoch 278/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8284 - loss: 0.4507 - val_accuracy: 0.3750 - val_loss: 1.3480
# Epoch 279/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8514 - loss: 0.4487 - val_accuracy: 0.4167 - val_loss: 1.3444
# Epoch 280/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8697 - loss: 0.4494 - val_accuracy: 0.3750 - val_loss: 1.3569
# Epoch 281/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8803 - loss: 0.4396 - val_accuracy: 0.4167 - val_loss: 1.3381
# Epoch 282/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9010 - loss: 0.4460 - val_accuracy: 0.4167 - val_loss: 1.3410
# Epoch 283/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8587 - loss: 0.4646 - val_accuracy: 0.3750 - val_loss: 1.3407
# Epoch 284/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8587 - loss: 0.4672 - val_accuracy: 0.4167 - val_loss: 1.3414
# Epoch 285/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8307 - loss: 0.4441 - val_accuracy: 0.4167 - val_loss: 1.3534
# Epoch 286/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8743 - loss: 0.4646 - val_accuracy: 0.3750 - val_loss: 1.3525
# Epoch 287/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8497 - loss: 0.4703 - val_accuracy: 0.4167 - val_loss: 1.3530
# Epoch 288/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8776 - loss: 0.4459 - val_accuracy: 0.4167 - val_loss: 1.3578
# Epoch 289/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8753 - loss: 0.4628 - val_accuracy: 0.4167 - val_loss: 1.3485
# Epoch 290/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8847 - loss: 0.4359 - val_accuracy: 0.3750 - val_loss: 1.3609
# Epoch 291/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8697 - loss: 0.4507 - val_accuracy: 0.3750 - val_loss: 1.3660
# Epoch 292/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8583 - loss: 0.4850 - val_accuracy: 0.3750 - val_loss: 1.3688
# Epoch 293/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8403 - loss: 0.4558 - val_accuracy: 0.3750 - val_loss: 1.3768
# Epoch 294/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8999 - loss: 0.4360 - val_accuracy: 0.4167 - val_loss: 1.3633
# Epoch 295/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8820 - loss: 0.4356 - val_accuracy: 0.3750 - val_loss: 1.3858
# Epoch 296/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8876 - loss: 0.4266 - val_accuracy: 0.4167 - val_loss: 1.3886
# Epoch 297/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8883 - loss: 0.4531 - val_accuracy: 0.3750 - val_loss: 1.4037
# Epoch 298/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8710 - loss: 0.4526 - val_accuracy: 0.3750 - val_loss: 1.3979
# Epoch 299/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8816 - loss: 0.4493 - val_accuracy: 0.3750 - val_loss: 1.4070
# Epoch 300/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8733 - loss: 0.4226 - val_accuracy: 0.3750 - val_loss: 1.4161

# %% [markdown]
# **Which activations did you use in the middle layers? Why was softmax used in the last layer?**

# %% [markdown]
# In our neural network, we used ReLU (Rectified Linear Unit) activation functions in all the middle (hidden) layers.
# We used Softmax in the last layer because the network is designed for multi-class classification. Softmax converts the raw output scores from the final layer into a probability distribution over the 5 classes (Very Low, Low, Average, High, Very High), ensuring that the sum of the output probabilities equals 1. This makes it suitable for computing the categorical crossentropy loss during training.

# %% [markdown]
# **Was it a good idea to train for 300 epochs? Should you train a bit more? Why or why not?**

# %% [markdown]
# NO. The training accuracy is very high (93.75%) and the training loss is low (0.3989), which indicates that the model fits the training data extremely well. However, the validation accuracy is only 41.67% with a much higher validation loss (1.6291). This large gap between training and validation performance is a clear sign of overfitting.

# %% [markdown]
# **Why is loss='categorical_crossentropy' and optimizer='sgd'? Would you want to change something? Why / Why not?**

# %% [markdown]
# This loss is used for multi-class classification problems where the targets are one-hot encoded. It measures the difference between the predicted probability distribution (from the softmax output) and the actual distribution. Given that our model outputs probabilities for 5 classes and our targets are one-hot encoded, categorical_crossentropy is the appropriate choice.
# Stochastic Gradient Descent (SGD) updates model parameters by computing the gradient on small batches of data.
#
# changes:
# SGD has some drawbacks: it may converge slowly, can get stuck in local minima, and is sensitive to the choice of learning rate. So, replace 'sgd' with an adaptive optimizer such as 'adam' might improve convergence speed and overall performance.

# %% [markdown]
# **Can you try getting the model's training history out and plotting the curves?**

# %%
## Plot training and validation curves in a single plot
import matplotlib.pyplot as plt

history = keras_model.fit(preprocessor(X_train), y_train_onehot,
                           batch_size=20,
                           epochs=300,
                           validation_split=0.25)

fig, ax1 = plt.subplots(figsize=(8, 6))
ax2 = ax1.twinx()  # Create a second y-axis sharing the same x-axis

ax1.plot(history.history['loss'], color='red', label='Training Loss')
ax1.plot(history.history['val_loss'], color='blue', label='Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color='red')
ax1.tick_params(axis='y', labelcolor='red')

ax2.plot(history.history['accuracy'], color='green', label='Training Accuracy')
ax2.plot(history.history['val_accuracy'], color='orange', label='Validation Accuracy')
ax2.set_ylabel('Accuracy', color='green')
ax2.tick_params(axis='y', labelcolor='green')

lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
legend = ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper center',
                    bbox_to_anchor=(0.5, -0.15), ncol=2)
plt.subplots_adjust(bottom=0.3)

plt.tight_layout()
plt.title('Training and Validation Curves')
plt.show()
# Out:
# Epoch 1/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8253 - loss: 0.4633 - val_accuracy: 0.3750 - val_loss: 1.4173
# Epoch 2/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8687 - loss: 0.4545 - val_accuracy: 0.3750 - val_loss: 1.4073
# Epoch 3/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8749 - loss: 0.4635 - val_accuracy: 0.3750 - val_loss: 1.4185
# Epoch 4/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8437 - loss: 0.4794 - val_accuracy: 0.3750 - val_loss: 1.4160
# Epoch 5/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8280 - loss: 0.4466 - val_accuracy: 0.4583 - val_loss: 1.4142
# Epoch 6/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8956 - loss: 0.4346 - val_accuracy: 0.3750 - val_loss: 1.4274
# Epoch 7/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8926 - loss: 0.3833 - val_accuracy: 0.3750 - val_loss: 1.4241
# Epoch 8/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8856 - loss: 0.4424 - val_accuracy: 0.3750 - val_loss: 1.4349
# Epoch 9/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8866 - loss: 0.4096 - val_accuracy: 0.3750 - val_loss: 1.4289
# Epoch 10/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9072 - loss: 0.4197 - val_accuracy: 0.3750 - val_loss: 1.4280
# Epoch 11/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8487 - loss: 0.4157 - val_accuracy: 0.3750 - val_loss: 1.4391
# Epoch 12/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9166 - loss: 0.3939 - val_accuracy: 0.3750 - val_loss: 1.4491
# Epoch 13/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9479 - loss: 0.3941 - val_accuracy: 0.3750 - val_loss: 1.4448
# Epoch 14/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8643 - loss: 0.4132 - val_accuracy: 0.3750 - val_loss: 1.4470
# Epoch 15/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8822 - loss: 0.4340 - val_accuracy: 0.3750 - val_loss: 1.4532
# Epoch 16/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8766 - loss: 0.4321 - val_accuracy: 0.3750 - val_loss: 1.4717
# Epoch 17/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8649 - loss: 0.4372 - val_accuracy: 0.3750 - val_loss: 1.4586
# Epoch 18/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9022 - loss: 0.3986 - val_accuracy: 0.3750 - val_loss: 1.4542
# Epoch 19/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8626 - loss: 0.4092 - val_accuracy: 0.3750 - val_loss: 1.4648
# Epoch 20/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8683 - loss: 0.4345 - val_accuracy: 0.3750 - val_loss: 1.4733
# Epoch 21/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9116 - loss: 0.3818 - val_accuracy: 0.3750 - val_loss: 1.4861
# Epoch 22/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9212 - loss: 0.3767 - val_accuracy: 0.3750 - val_loss: 1.4695
# Epoch 23/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8999 - loss: 0.3676 - val_accuracy: 0.4167 - val_loss: 1.4720
# Epoch 24/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9112 - loss: 0.3976 - val_accuracy: 0.3750 - val_loss: 1.4892
# Epoch 25/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9049 - loss: 0.3666 - val_accuracy: 0.3750 - val_loss: 1.4889
# Epoch 26/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9129 - loss: 0.3926 - val_accuracy: 0.3750 - val_loss: 1.4906
# Epoch 27/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8866 - loss: 0.4076 - val_accuracy: 0.3750 - val_loss: 1.4989
# Epoch 28/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8929 - loss: 0.4223 - val_accuracy: 0.4167 - val_loss: 1.4846
# Epoch 29/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9212 - loss: 0.3828 - val_accuracy: 0.3750 - val_loss: 1.5061
# Epoch 30/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9249 - loss: 0.3503 - val_accuracy: 0.3750 - val_loss: 1.5005
# Epoch 31/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9272 - loss: 0.3793 - val_accuracy: 0.3750 - val_loss: 1.5029
# Epoch 32/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8893 - loss: 0.3926 - val_accuracy: 0.3750 - val_loss: 1.5099
# Epoch 33/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9475 - loss: 0.3414 - val_accuracy: 0.3750 - val_loss: 1.5145
# Epoch 34/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8845 - loss: 0.3768 - val_accuracy: 0.3750 - val_loss: 1.5136
# Epoch 35/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9335 - loss: 0.3691 - val_accuracy: 0.4583 - val_loss: 1.5139
# Epoch 36/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9089 - loss: 0.3697 - val_accuracy: 0.4167 - val_loss: 1.5295
# Epoch 37/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9452 - loss: 0.3438 - val_accuracy: 0.3750 - val_loss: 1.5255
# Epoch 38/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9285 - loss: 0.3529 - val_accuracy: 0.4167 - val_loss: 1.5092
# Epoch 39/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9212 - loss: 0.3652 - val_accuracy: 0.4167 - val_loss: 1.5335
# Epoch 40/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9166 - loss: 0.3580 - val_accuracy: 0.3750 - val_loss: 1.5385
# Epoch 41/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9329 - loss: 0.3395 - val_accuracy: 0.4167 - val_loss: 1.5625
# Epoch 42/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9289 - loss: 0.3590 - val_accuracy: 0.3750 - val_loss: 1.5646
# Epoch 43/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9335 - loss: 0.3419 - val_accuracy: 0.4583 - val_loss: 1.5395
# Epoch 44/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8912 - loss: 0.3823 - val_accuracy: 0.4583 - val_loss: 1.5652
# Epoch 45/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9429 - loss: 0.3214 - val_accuracy: 0.4583 - val_loss: 1.5444
# Epoch 46/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9179 - loss: 0.3117 - val_accuracy: 0.4167 - val_loss: 1.5545
# Epoch 47/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8849 - loss: 0.3682 - val_accuracy: 0.4583 - val_loss: 1.5584
# Epoch 48/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9006 - loss: 0.3687 - val_accuracy: 0.4583 - val_loss: 1.5727
# Epoch 49/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9122 - loss: 0.3548 - val_accuracy: 0.4583 - val_loss: 1.5730
# Epoch 50/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9245 - loss: 0.3557 - val_accuracy: 0.4167 - val_loss: 1.5836
# Epoch 51/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9072 - loss: 0.3457 - val_accuracy: 0.4583 - val_loss: 1.5874
# Epoch 52/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9139 - loss: 0.3299 - val_accuracy: 0.4583 - val_loss: 1.5796
# Epoch 53/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9618 - loss: 0.3056 - val_accuracy: 0.4167 - val_loss: 1.5703
# Epoch 54/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9329 - loss: 0.3332 - val_accuracy: 0.4167 - val_loss: 1.5955
# Epoch 55/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9062 - loss: 0.3518 - val_accuracy: 0.4583 - val_loss: 1.6040
# Epoch 56/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9285 - loss: 0.3436 - val_accuracy: 0.4167 - val_loss: 1.6166
# Epoch 57/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9285 - loss: 0.3415 - val_accuracy: 0.4167 - val_loss: 1.6079
# Epoch 58/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9012 - loss: 0.3338 - val_accuracy: 0.4167 - val_loss: 1.6351
# Epoch 59/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8766 - loss: 0.3521 - val_accuracy: 0.4167 - val_loss: 1.6501
# Epoch 60/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9145 - loss: 0.3082 - val_accuracy: 0.4583 - val_loss: 1.6273
# Epoch 61/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9435 - loss: 0.3172 - val_accuracy: 0.4583 - val_loss: 1.6307
# Epoch 62/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9235 - loss: 0.3544 - val_accuracy: 0.4167 - val_loss: 1.6371
# Epoch 63/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8722 - loss: 0.3497 - val_accuracy: 0.4583 - val_loss: 1.6410
# Epoch 64/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9435 - loss: 0.3078 - val_accuracy: 0.4583 - val_loss: 1.6355
# Epoch 65/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8956 - loss: 0.3601 - val_accuracy: 0.4167 - val_loss: 1.6363
# Epoch 66/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8912 - loss: 0.3470 - val_accuracy: 0.4167 - val_loss: 1.6482
# Epoch 67/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9385 - loss: 0.3112 - val_accuracy: 0.4167 - val_loss: 1.6665
# Epoch 68/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9279 - loss: 0.3159 - val_accuracy: 0.4167 - val_loss: 1.6491
# Epoch 69/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8956 - loss: 0.3323 - val_accuracy: 0.4167 - val_loss: 1.6584
# Epoch 70/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9412 - loss: 0.2894 - val_accuracy: 0.4167 - val_loss: 1.6915
# Epoch 71/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9325 - loss: 0.3268 - val_accuracy: 0.4167 - val_loss: 1.6883
# Epoch 72/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9095 - loss: 0.3162 - val_accuracy: 0.4167 - val_loss: 1.6851
# Epoch 73/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9385 - loss: 0.3274 - val_accuracy: 0.4583 - val_loss: 1.6959
# Epoch 74/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9335 - loss: 0.2950 - val_accuracy: 0.4167 - val_loss: 1.6880
# Epoch 75/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9141 - loss: 0.3414 - val_accuracy: 0.4583 - val_loss: 1.7089
# Epoch 76/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9162 - loss: 0.2969 - val_accuracy: 0.4583 - val_loss: 1.7055
# Epoch 77/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9408 - loss: 0.2876 - val_accuracy: 0.4167 - val_loss: 1.7008
# Epoch 78/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8716 - loss: 0.3176 - val_accuracy: 0.3750 - val_loss: 1.7024
# Epoch 79/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9475 - loss: 0.3119 - val_accuracy: 0.3750 - val_loss: 1.7229
# Epoch 80/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9245 - loss: 0.3171 - val_accuracy: 0.4167 - val_loss: 1.7278
# Epoch 81/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9341 - loss: 0.3117 - val_accuracy: 0.4167 - val_loss: 1.7437
# Epoch 82/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9152 - loss: 0.2873 - val_accuracy: 0.4167 - val_loss: 1.7350
# Epoch 83/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9152 - loss: 0.3055 - val_accuracy: 0.4167 - val_loss: 1.7676
# Epoch 84/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9385 - loss: 0.2968 - val_accuracy: 0.4167 - val_loss: 1.7474
# Epoch 85/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8862 - loss: 0.3068 - val_accuracy: 0.4167 - val_loss: 1.7438
# Epoch 86/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9295 - loss: 0.2641 - val_accuracy: 0.4167 - val_loss: 1.7455
# Epoch 87/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9302 - loss: 0.2866 - val_accuracy: 0.4583 - val_loss: 1.7734
# Epoch 88/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9441 - loss: 0.2852 - val_accuracy: 0.4583 - val_loss: 1.7698
# Epoch 89/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9268 - loss: 0.2920 - val_accuracy: 0.4167 - val_loss: 1.8005
# Epoch 90/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9202 - loss: 0.3126 - val_accuracy: 0.4167 - val_loss: 1.8100
# Epoch 91/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8962 - loss: 0.3002 - val_accuracy: 0.4167 - val_loss: 1.8192
# Epoch 92/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9133 - loss: 0.2714 - val_accuracy: 0.4167 - val_loss: 1.8144
# Epoch 93/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9252 - loss: 0.3221 - val_accuracy: 0.4167 - val_loss: 1.8146
# Epoch 94/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9714 - loss: 0.2624 - val_accuracy: 0.4167 - val_loss: 1.7883
# Epoch 95/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9206 - loss: 0.2808 - val_accuracy: 0.4167 - val_loss: 1.7977
# Epoch 96/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9425 - loss: 0.2605 - val_accuracy: 0.3750 - val_loss: 1.7908
# Epoch 97/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9325 - loss: 0.2868 - val_accuracy: 0.4167 - val_loss: 1.8179
# Epoch 98/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9285 - loss: 0.2699 - val_accuracy: 0.4167 - val_loss: 1.8327
# Epoch 99/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9335 - loss: 0.2887 - val_accuracy: 0.4167 - val_loss: 1.8299
# Epoch 100/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9302 - loss: 0.2928 - val_accuracy: 0.4167 - val_loss: 1.8307
# Epoch 101/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9235 - loss: 0.2596 - val_accuracy: 0.4167 - val_loss: 1.8397
# Epoch 102/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9345 - loss: 0.2439 - val_accuracy: 0.4167 - val_loss: 1.8558
# Epoch 103/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9252 - loss: 0.2687 - val_accuracy: 0.4167 - val_loss: 1.8580
# Epoch 104/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9235 - loss: 0.2525 - val_accuracy: 0.4583 - val_loss: 1.8699
# Epoch 105/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9485 - loss: 0.2602 - val_accuracy: 0.4167 - val_loss: 1.8570
# Epoch 106/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8949 - loss: 0.2677 - val_accuracy: 0.4583 - val_loss: 1.8613
# Epoch 107/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9391 - loss: 0.2610 - val_accuracy: 0.4167 - val_loss: 1.9011
# Epoch 108/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9425 - loss: 0.2561 - val_accuracy: 0.3750 - val_loss: 1.8844
# Epoch 109/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9475 - loss: 0.2627 - val_accuracy: 0.4167 - val_loss: 1.8927
# Epoch 110/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9452 - loss: 0.2442 - val_accuracy: 0.4583 - val_loss: 1.8932
# Epoch 111/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9631 - loss: 0.2408 - val_accuracy: 0.4167 - val_loss: 1.9219
# Epoch 112/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9491 - loss: 0.2455 - val_accuracy: 0.4167 - val_loss: 1.9266
# Epoch 113/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9541 - loss: 0.2525 - val_accuracy: 0.4583 - val_loss: 1.8897
# Epoch 114/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9771 - loss: 0.2421 - val_accuracy: 0.4167 - val_loss: 1.9276
# Epoch 115/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9518 - loss: 0.2313 - val_accuracy: 0.4167 - val_loss: 1.9225
# Epoch 116/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9481 - loss: 0.2320 - val_accuracy: 0.4583 - val_loss: 1.9303
# Epoch 117/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9531 - loss: 0.2569 - val_accuracy: 0.4583 - val_loss: 1.9269
# Epoch 118/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8995 - loss: 0.2580 - val_accuracy: 0.4167 - val_loss: 1.9754
# Epoch 119/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9581 - loss: 0.2641 - val_accuracy: 0.4167 - val_loss: 1.9907
# Epoch 120/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9241 - loss: 0.2821 - val_accuracy: 0.4167 - val_loss: 1.9672
# Epoch 121/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9491 - loss: 0.2408 - val_accuracy: 0.4167 - val_loss: 1.9672
# Epoch 122/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9564 - loss: 0.2546 - val_accuracy: 0.4167 - val_loss: 1.9625
# Epoch 123/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9821 - loss: 0.2044 - val_accuracy: 0.4167 - val_loss: 1.9747
# Epoch 124/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9771 - loss: 0.2223 - val_accuracy: 0.4167 - val_loss: 1.9791
# Epoch 125/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9854 - loss: 0.2182 - val_accuracy: 0.4167 - val_loss: 2.0018
# Epoch 126/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9341 - loss: 0.2524 - val_accuracy: 0.4583 - val_loss: 1.9934
# Epoch 127/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9681 - loss: 0.2106 - val_accuracy: 0.4167 - val_loss: 1.9891
# Epoch 128/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9704 - loss: 0.2301 - val_accuracy: 0.4167 - val_loss: 1.9690
# Epoch 129/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9614 - loss: 0.2283 - val_accuracy: 0.4167 - val_loss: 1.9938
# Epoch 130/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9764 - loss: 0.2281 - val_accuracy: 0.4167 - val_loss: 2.0144
# Epoch 131/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9821 - loss: 0.2279 - val_accuracy: 0.4583 - val_loss: 2.0247
# Epoch 132/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9748 - loss: 0.2096 - val_accuracy: 0.4167 - val_loss: 1.9991
# Epoch 133/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9291 - loss: 0.2644 - val_accuracy: 0.4583 - val_loss: 2.0039
# Epoch 134/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9664 - loss: 0.2071 - val_accuracy: 0.4583 - val_loss: 2.0001
# Epoch 135/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9531 - loss: 0.2308 - val_accuracy: 0.4583 - val_loss: 2.0151
# Epoch 136/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9860 - loss: 0.2191 - val_accuracy: 0.4583 - val_loss: 2.0341
# Epoch 137/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9664 - loss: 0.2174 - val_accuracy: 0.4583 - val_loss: 2.0380
# Epoch 138/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9771 - loss: 0.2168 - val_accuracy: 0.4167 - val_loss: 2.0629
# Epoch 139/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9910 - loss: 0.2001 - val_accuracy: 0.4583 - val_loss: 2.0745
# Epoch 140/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9625 - loss: 0.2079 - val_accuracy: 0.4583 - val_loss: 2.0753
# Epoch 141/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9631 - loss: 0.2277 - val_accuracy: 0.4167 - val_loss: 2.0923
# Epoch 142/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9821 - loss: 0.2055 - val_accuracy: 0.4583 - val_loss: 2.0720
# Epoch 143/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9681 - loss: 0.1926 - val_accuracy: 0.4583 - val_loss: 2.0735
# Epoch 144/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9475 - loss: 0.2058 - val_accuracy: 0.4167 - val_loss: 2.1054
# Epoch 145/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9531 - loss: 0.2178 - val_accuracy: 0.4583 - val_loss: 2.1122
# Epoch 146/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9212 - loss: 0.2360 - val_accuracy: 0.4583 - val_loss: 2.1333
# Epoch 147/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9671 - loss: 0.2205 - val_accuracy: 0.4583 - val_loss: 2.1328
# Epoch 148/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9408 - loss: 0.2231 - val_accuracy: 0.3750 - val_loss: 2.1190
# Epoch 149/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9821 - loss: 0.1883 - val_accuracy: 0.4583 - val_loss: 2.1230
# Epoch 150/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9731 - loss: 0.1914 - val_accuracy: 0.4583 - val_loss: 2.1439
# Epoch 151/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9704 - loss: 0.2171 - val_accuracy: 0.4167 - val_loss: 2.1505
# Epoch 152/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9564 - loss: 0.2018 - val_accuracy: 0.4167 - val_loss: 2.1606
# Epoch 153/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9521 - loss: 0.1983 - val_accuracy: 0.4583 - val_loss: 2.1666
# Epoch 154/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9614 - loss: 0.2000 - val_accuracy: 0.4167 - val_loss: 2.1549
# Epoch 155/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9431 - loss: 0.2084 - val_accuracy: 0.4167 - val_loss: 2.1530
# Epoch 156/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9771 - loss: 0.1957 - val_accuracy: 0.4583 - val_loss: 2.1623
# Epoch 157/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9910 - loss: 0.1949 - val_accuracy: 0.4167 - val_loss: 2.1684
# Epoch 158/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9804 - loss: 0.1858 - val_accuracy: 0.4583 - val_loss: 2.1789
# Epoch 159/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9714 - loss: 0.1830 - val_accuracy: 0.4583 - val_loss: 2.1820
# Epoch 160/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9425 - loss: 0.1987 - val_accuracy: 0.4583 - val_loss: 2.1892
# Epoch 161/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9910 - loss: 0.1775 - val_accuracy: 0.5000 - val_loss: 2.1786
# Epoch 162/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9804 - loss: 0.1889 - val_accuracy: 0.4583 - val_loss: 2.1861
# Epoch 163/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9671 - loss: 0.1836 - val_accuracy: 0.4583 - val_loss: 2.1821
# Epoch 164/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9804 - loss: 0.1733 - val_accuracy: 0.4583 - val_loss: 2.2077
# Epoch 165/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9771 - loss: 0.1749 - val_accuracy: 0.4583 - val_loss: 2.2029
# Epoch 166/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9704 - loss: 0.1710 - val_accuracy: 0.4583 - val_loss: 2.2259
# Epoch 167/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9225 - loss: 0.2075 - val_accuracy: 0.4167 - val_loss: 2.2312
# Epoch 168/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9608 - loss: 0.1884 - val_accuracy: 0.4583 - val_loss: 2.2536
# Epoch 169/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9731 - loss: 0.1873 - val_accuracy: 0.4583 - val_loss: 2.2604
# Epoch 170/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9760 - loss: 0.1919 - val_accuracy: 0.4167 - val_loss: 2.2847
# Epoch 171/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9721 - loss: 0.1646 - val_accuracy: 0.4167 - val_loss: 2.2810
# Epoch 172/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9944 - loss: 0.1871 - val_accuracy: 0.4167 - val_loss: 2.2717
# Epoch 173/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9771 - loss: 0.1685 - val_accuracy: 0.4167 - val_loss: 2.2844
# Epoch 174/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9910 - loss: 0.1656 - val_accuracy: 0.4583 - val_loss: 2.2548
# Epoch 175/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9621 - loss: 0.1850 - val_accuracy: 0.4583 - val_loss: 2.2950
# Epoch 176/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.9821 - loss: 0.1812 - val_accuracy: 0.4167 - val_loss: 2.3086
# Epoch 177/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9671 - loss: 0.1803 - val_accuracy: 0.4583 - val_loss: 2.3039
# Epoch 178/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9910 - loss: 0.1720 - val_accuracy: 0.4583 - val_loss: 2.3279
# Epoch 179/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9760 - loss: 0.1687 - val_accuracy: 0.4583 - val_loss: 2.3329
# Epoch 180/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9854 - loss: 0.1559 - val_accuracy: 0.4167 - val_loss: 2.3266
# Epoch 181/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9614 - loss: 0.1710 - val_accuracy: 0.4167 - val_loss: 2.3201
# Epoch 182/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9821 - loss: 0.1703 - val_accuracy: 0.4583 - val_loss: 2.3305
# Epoch 183/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9748 - loss: 0.1549 - val_accuracy: 0.5000 - val_loss: 2.3306
# Epoch 184/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9621 - loss: 0.1785 - val_accuracy: 0.4583 - val_loss: 2.3522
# Epoch 185/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9671 - loss: 0.1790 - val_accuracy: 0.4167 - val_loss: 2.3207
# Epoch 186/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9521 - loss: 0.2014 - val_accuracy: 0.4583 - val_loss: 2.3564
# Epoch 187/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9910 - loss: 0.1636 - val_accuracy: 0.4583 - val_loss: 2.3632
# Epoch 188/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9910 - loss: 0.1396 - val_accuracy: 0.4167 - val_loss: 2.3546
# Epoch 189/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9771 - loss: 0.1583 - val_accuracy: 0.4583 - val_loss: 2.4082
# Epoch 190/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9714 - loss: 0.1513 - val_accuracy: 0.4583 - val_loss: 2.3821
# Epoch 191/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9910 - loss: 0.1525 - val_accuracy: 0.4583 - val_loss: 2.3807
# Epoch 192/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9804 - loss: 0.1560 - val_accuracy: 0.4583 - val_loss: 2.4034
# Epoch 193/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9804 - loss: 0.1497 - val_accuracy: 0.4167 - val_loss: 2.4110
# Epoch 194/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.1443 - val_accuracy: 0.4167 - val_loss: 2.4253
# Epoch 195/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9804 - loss: 0.1665 - val_accuracy: 0.4167 - val_loss: 2.4364
# Epoch 196/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9910 - loss: 0.1495 - val_accuracy: 0.4583 - val_loss: 2.4242
# Epoch 197/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9760 - loss: 0.1698 - val_accuracy: 0.4583 - val_loss: 2.4395
# Epoch 198/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9860 - loss: 0.1444 - val_accuracy: 0.4167 - val_loss: 2.4508
# Epoch 199/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9944 - loss: 0.1381 - val_accuracy: 0.4583 - val_loss: 2.4266
# Epoch 200/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.1484 - val_accuracy: 0.4583 - val_loss: 2.4285
# Epoch 201/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9481 - loss: 0.1782 - val_accuracy: 0.5000 - val_loss: 2.4506
# Epoch 202/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9704 - loss: 0.1759 - val_accuracy: 0.4583 - val_loss: 2.4720
# Epoch 203/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9771 - loss: 0.1500 - val_accuracy: 0.4167 - val_loss: 2.4763
# Epoch 204/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.1579 - val_accuracy: 0.5000 - val_loss: 2.4792
# Epoch 205/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9614 - loss: 0.1547 - val_accuracy: 0.4583 - val_loss: 2.4811
# Epoch 206/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9910 - loss: 0.1550 - val_accuracy: 0.4583 - val_loss: 2.4854
# Epoch 207/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9804 - loss: 0.1351 - val_accuracy: 0.4583 - val_loss: 2.4854
# Epoch 208/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.1591 - val_accuracy: 0.4167 - val_loss: 2.5161
# Epoch 209/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.1525 - val_accuracy: 0.4167 - val_loss: 2.5015
# Epoch 210/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9721 - loss: 0.1588 - val_accuracy: 0.4583 - val_loss: 2.5256
# Epoch 211/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9860 - loss: 0.1519 - val_accuracy: 0.4583 - val_loss: 2.5157
# Epoch 212/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9860 - loss: 0.1377 - val_accuracy: 0.4583 - val_loss: 2.5128
# Epoch 213/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9860 - loss: 0.1418 - val_accuracy: 0.4583 - val_loss: 2.5531
# Epoch 214/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9771 - loss: 0.1415 - val_accuracy: 0.4583 - val_loss: 2.5328
# Epoch 215/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.9821 - loss: 0.1394 - val_accuracy: 0.4167 - val_loss: 2.5488
# Epoch 216/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9944 - loss: 0.1475 - val_accuracy: 0.4167 - val_loss: 2.5894
# Epoch 217/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9910 - loss: 0.1430 - val_accuracy: 0.4167 - val_loss: 2.5572
# Epoch 218/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 0.9760 - loss: 0.1430 - val_accuracy: 0.4167 - val_loss: 2.5589
# Epoch 219/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9621 - loss: 0.1708 - val_accuracy: 0.4167 - val_loss: 2.5731
# Epoch 220/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.9771 - loss: 0.1404 - val_accuracy: 0.4167 - val_loss: 2.6004
# Epoch 221/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9944 - loss: 0.1252 - val_accuracy: 0.4167 - val_loss: 2.6165
# Epoch 222/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 1.0000 - loss: 0.1197 - val_accuracy: 0.4583 - val_loss: 2.6111
# Epoch 223/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9910 - loss: 0.1443 - val_accuracy: 0.4583 - val_loss: 2.6039
# Epoch 224/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9944 - loss: 0.1289 - val_accuracy: 0.4583 - val_loss: 2.5918
# Epoch 225/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 1.0000 - loss: 0.1325 - val_accuracy: 0.4583 - val_loss: 2.6162
# Epoch 226/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - accuracy: 0.9621 - loss: 0.1352 - val_accuracy: 0.4167 - val_loss: 2.6279
# Epoch 227/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9944 - loss: 0.1258 - val_accuracy: 0.4167 - val_loss: 2.6441
# Epoch 228/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9854 - loss: 0.1213 - val_accuracy: 0.5000 - val_loss: 2.6462
# Epoch 229/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9704 - loss: 0.1285 - val_accuracy: 0.4167 - val_loss: 2.6482
# Epoch 230/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9860 - loss: 0.1292 - val_accuracy: 0.4583 - val_loss: 2.6606
# Epoch 231/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9910 - loss: 0.1233 - val_accuracy: 0.4583 - val_loss: 2.6374
# Epoch 232/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9771 - loss: 0.1261 - val_accuracy: 0.5000 - val_loss: 2.6312
# Epoch 233/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9671 - loss: 0.1269 - val_accuracy: 0.4583 - val_loss: 2.6598
# Epoch 234/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9944 - loss: 0.1152 - val_accuracy: 0.4167 - val_loss: 2.7065
# Epoch 235/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9760 - loss: 0.1282 - val_accuracy: 0.4167 - val_loss: 2.6940
# Epoch 236/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9910 - loss: 0.1239 - val_accuracy: 0.4583 - val_loss: 2.6997
# Epoch 237/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9910 - loss: 0.1172 - val_accuracy: 0.4583 - val_loss: 2.7081
# Epoch 238/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9944 - loss: 0.1217 - val_accuracy: 0.5000 - val_loss: 2.7153
# Epoch 239/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9764 - loss: 0.1111 - val_accuracy: 0.4583 - val_loss: 2.6793
# Epoch 240/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.1122 - val_accuracy: 0.4583 - val_loss: 2.7016
# Epoch 241/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.1150 - val_accuracy: 0.4583 - val_loss: 2.7116
# Epoch 242/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9760 - loss: 0.1246 - val_accuracy: 0.4167 - val_loss: 2.7296
# Epoch 243/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9944 - loss: 0.1116 - val_accuracy: 0.4167 - val_loss: 2.7394
# Epoch 244/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9671 - loss: 0.1426 - val_accuracy: 0.4583 - val_loss: 2.7215
# Epoch 245/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9910 - loss: 0.1100 - val_accuracy: 0.4583 - val_loss: 2.7239
# Epoch 246/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9721 - loss: 0.1306 - val_accuracy: 0.4583 - val_loss: 2.7528
# Epoch 247/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.1168 - val_accuracy: 0.4583 - val_loss: 2.7378
# Epoch 248/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9910 - loss: 0.1066 - val_accuracy: 0.4167 - val_loss: 2.7559
# Epoch 249/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9944 - loss: 0.1145 - val_accuracy: 0.4583 - val_loss: 2.7799
# Epoch 250/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9944 - loss: 0.1090 - val_accuracy: 0.4583 - val_loss: 2.7640
# Epoch 251/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9944 - loss: 0.0976 - val_accuracy: 0.4583 - val_loss: 2.7698
# Epoch 252/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9944 - loss: 0.1033 - val_accuracy: 0.4167 - val_loss: 2.7909
# Epoch 253/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9621 - loss: 0.1379 - val_accuracy: 0.4167 - val_loss: 2.7915
# Epoch 254/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.1191 - val_accuracy: 0.4167 - val_loss: 2.8130
# Epoch 255/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9860 - loss: 0.1148 - val_accuracy: 0.4167 - val_loss: 2.8309
# Epoch 256/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9910 - loss: 0.1185 - val_accuracy: 0.4167 - val_loss: 2.8299
# Epoch 257/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.1005 - val_accuracy: 0.4167 - val_loss: 2.8325
# Epoch 258/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9860 - loss: 0.1032 - val_accuracy: 0.5000 - val_loss: 2.8389
# Epoch 259/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9760 - loss: 0.1044 - val_accuracy: 0.4167 - val_loss: 2.8415
# Epoch 260/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.1149 - val_accuracy: 0.4167 - val_loss: 2.8657
# Epoch 261/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.1151 - val_accuracy: 0.4583 - val_loss: 2.8681
# Epoch 262/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.1094 - val_accuracy: 0.4583 - val_loss: 2.8769
# Epoch 263/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0957 - val_accuracy: 0.5000 - val_loss: 2.8834
# Epoch 264/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9910 - loss: 0.1024 - val_accuracy: 0.4167 - val_loss: 2.9157
# Epoch 265/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9910 - loss: 0.1008 - val_accuracy: 0.4167 - val_loss: 2.8982
# Epoch 266/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.1014 - val_accuracy: 0.4167 - val_loss: 2.9084
# Epoch 267/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0967 - val_accuracy: 0.4167 - val_loss: 2.9026
# Epoch 268/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.1043 - val_accuracy: 0.4167 - val_loss: 2.9113
# Epoch 269/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0936 - val_accuracy: 0.5000 - val_loss: 2.9099
# Epoch 270/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9760 - loss: 0.1152 - val_accuracy: 0.4583 - val_loss: 2.9159
# Epoch 271/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0919 - val_accuracy: 0.4583 - val_loss: 2.9189
# Epoch 272/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9910 - loss: 0.0906 - val_accuracy: 0.4167 - val_loss: 2.9361
# Epoch 273/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0963 - val_accuracy: 0.4583 - val_loss: 2.9434
# Epoch 274/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 0.0902 - val_accuracy: 0.4167 - val_loss: 2.9617
# Epoch 275/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.1098 - val_accuracy: 0.4167 - val_loss: 2.9691
# Epoch 276/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9760 - loss: 0.1020 - val_accuracy: 0.4167 - val_loss: 2.9785
# Epoch 277/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.0915 - val_accuracy: 0.4167 - val_loss: 2.9575
# Epoch 278/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9910 - loss: 0.1096 - val_accuracy: 0.4167 - val_loss: 2.9731
# Epoch 279/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0915 - val_accuracy: 0.5000 - val_loss: 2.9705
# Epoch 280/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9910 - loss: 0.0895 - val_accuracy: 0.4583 - val_loss: 2.9807
# Epoch 281/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9760 - loss: 0.0999 - val_accuracy: 0.4583 - val_loss: 2.9800
# Epoch 282/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9760 - loss: 0.1043 - val_accuracy: 0.4167 - val_loss: 2.9834
# Epoch 283/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0945 - val_accuracy: 0.4583 - val_loss: 2.9906
# Epoch 284/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0949 - val_accuracy: 0.4583 - val_loss: 3.0107
# Epoch 285/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0875 - val_accuracy: 0.4583 - val_loss: 3.0216
# Epoch 286/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0846 - val_accuracy: 0.4583 - val_loss: 3.0295
# Epoch 287/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0841 - val_accuracy: 0.4583 - val_loss: 3.0383
# Epoch 288/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0829 - val_accuracy: 0.4167 - val_loss: 3.0440
# Epoch 289/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.1037 - val_accuracy: 0.4583 - val_loss: 3.0311
# Epoch 290/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9860 - loss: 0.0850 - val_accuracy: 0.4583 - val_loss: 3.0370
# Epoch 291/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9860 - loss: 0.0912 - val_accuracy: 0.4583 - val_loss: 3.0506
# Epoch 292/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0771 - val_accuracy: 0.4167 - val_loss: 3.0771
# Epoch 293/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9760 - loss: 0.1143 - val_accuracy: 0.4167 - val_loss: 3.0785
# Epoch 294/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0896 - val_accuracy: 0.4583 - val_loss: 3.0763
# Epoch 295/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0826 - val_accuracy: 0.4167 - val_loss: 3.0828
# Epoch 296/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0876 - val_accuracy: 0.4583 - val_loss: 3.0979
# Epoch 297/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0765 - val_accuracy: 0.4583 - val_loss: 3.0924
# Epoch 298/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0986 - val_accuracy: 0.4583 - val_loss: 3.0934
# Epoch 299/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0765 - val_accuracy: 0.4583 - val_loss: 3.1122
# Epoch 300/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0777 - val_accuracy: 0.4583 - val_loss: 3.1077

# %%
#-- Generate predicted y values

import numpy as np
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix


predicted_probs = keras_model.predict(preprocessor(X_test))

prediction_column_index = np.argmax(predicted_probs, axis=1)

categories = list(y_train.astype('category').cat.categories)
prediction_labels = [categories[i] for i in prediction_column_index]

true_labels = y_test.tolist()


# Evaluate model performance
accuracy = accuracy_score(true_labels, prediction_labels)
print("Accuracy:", accuracy)
print("Classification Report:")
print(classification_report(true_labels, prediction_labels))
print("Confusion Matrix:")
print(confusion_matrix(true_labels, prediction_labels))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Accuracy: 0.5952380952380952
# Classification Report:
#               precision    recall  f1-score   support
#
#      Average       0.62      0.62      0.62         8
#         High       0.43      0.38      0.40         8
#          Low       0.57      0.50      0.53         8
#    Very High       0.64      0.78      0.70         9
#     Very Low       0.67      0.67      0.67         9
#
#     accuracy                           0.60        42
#    macro avg       0.59      0.59      0.58        42
# weighted avg       0.59      0.60      0.59        42
#
# Confusion Matrix:
# [[5 2 0 1 0]
#  [2 3 0 3 0]
#  [1 0 4 0 3]
#  [0 2 0 7 0]
#  [0 0 3 0 6]]

# %% [markdown]
# Implement regularization techniques such as Dropout and Batch Normalization to improve model generalization and observe change in performance. <br>
# Note: Observe the training and testing loss and accuracy.

# %%
# Your code here:
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt

feature_count = preprocessor(X_train).shape[1]

# Build a deep learning model with regularization (Dropout and Batch Normalization)
keras_model_reg = Sequential([
    Dense(128, input_dim=feature_count, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),  # Dropout rate of 30%

    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),

    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),

    Dense(32, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),

    Dense(5, activation='softmax')  # 5 neurons for 5 classes
])

keras_model_reg.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

y_train_onehot = to_categorical(y_train.astype('category').cat.codes)

history_reg = keras_model_reg.fit(preprocessor(X_train), y_train_onehot,
                                  batch_size=20,
                                  epochs=300,
                                  validation_split=0.25)

plt.figure(figsize=(14,6))

# Loss plot
plt.subplot(1, 2, 1)
plt.plot(history_reg.history['loss'], label='Training Loss')
plt.plot(history_reg.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Curves')
plt.legend()

# Accuracy plot
plt.subplot(1, 2, 2)
plt.plot(history_reg.history['accuracy'], label='Training Accuracy')
plt.plot(history_reg.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Curves')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.2145 - loss: 2.5628 - val_accuracy: 0.0417 - val_loss: 1.6240
# Epoch 2/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.2441 - loss: 2.0366 - val_accuracy: 0.1667 - val_loss: 1.6091
# Epoch 3/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.2251 - loss: 2.7870 - val_accuracy: 0.3750 - val_loss: 1.5954
# Epoch 4/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.2770 - loss: 2.0614 - val_accuracy: 0.4583 - val_loss: 1.5810
# Epoch 5/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.3389 - loss: 1.8883 - val_accuracy: 0.4583 - val_loss: 1.5708
# Epoch 6/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.3615 - loss: 1.7650 - val_accuracy: 0.4583 - val_loss: 1.5629
# Epoch 7/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.3502 - loss: 1.9747 - val_accuracy: 0.5000 - val_loss: 1.5511
# Epoch 8/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.3158 - loss: 1.7194 - val_accuracy: 0.5000 - val_loss: 1.5392
# Epoch 9/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4200 - loss: 1.6572 - val_accuracy: 0.5000 - val_loss: 1.5279
# Epoch 10/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.3246 - loss: 1.8672 - val_accuracy: 0.5000 - val_loss: 1.5171
# Epoch 11/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.3721 - loss: 1.4872 - val_accuracy: 0.5000 - val_loss: 1.5057
# Epoch 12/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.3638 - loss: 1.6108 - val_accuracy: 0.5000 - val_loss: 1.4956
# Epoch 13/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4077 - loss: 1.4547 - val_accuracy: 0.4583 - val_loss: 1.4837
# Epoch 14/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.3352 - loss: 1.5194 - val_accuracy: 0.5000 - val_loss: 1.4760
# Epoch 15/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4369 - loss: 1.4726 - val_accuracy: 0.5000 - val_loss: 1.4679
# Epoch 16/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5462 - loss: 1.3504 - val_accuracy: 0.4583 - val_loss: 1.4610
# Epoch 17/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.3448 - loss: 1.6285 - val_accuracy: 0.5000 - val_loss: 1.4539
# Epoch 18/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5174 - loss: 1.2014 - val_accuracy: 0.4167 - val_loss: 1.4484
# Epoch 19/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4369 - loss: 1.3435 - val_accuracy: 0.4167 - val_loss: 1.4420
# Epoch 20/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5397 - loss: 1.3597 - val_accuracy: 0.3333 - val_loss: 1.4334
# Epoch 21/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5431 - loss: 1.2185 - val_accuracy: 0.3333 - val_loss: 1.4258
# Epoch 22/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4932 - loss: 1.2362 - val_accuracy: 0.3333 - val_loss: 1.4197
# Epoch 23/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.4808 - loss: 1.3116 - val_accuracy: 0.3333 - val_loss: 1.4121
# Epoch 24/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5462 - loss: 1.1160 - val_accuracy: 0.3333 - val_loss: 1.4038
# Epoch 25/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4863 - loss: 1.3886 - val_accuracy: 0.3333 - val_loss: 1.3939
# Epoch 26/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5514 - loss: 1.1030 - val_accuracy: 0.3333 - val_loss: 1.3834
# Epoch 27/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5245 - loss: 1.2067 - val_accuracy: 0.3333 - val_loss: 1.3746
# Epoch 28/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4040 - loss: 1.3571 - val_accuracy: 0.3750 - val_loss: 1.3665
# Epoch 29/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6056 - loss: 1.0988 - val_accuracy: 0.3750 - val_loss: 1.3598
# Epoch 30/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5074 - loss: 1.1667 - val_accuracy: 0.3750 - val_loss: 1.3539
# Epoch 31/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5877 - loss: 0.9039 - val_accuracy: 0.3333 - val_loss: 1.3493
# Epoch 32/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5787 - loss: 1.2110 - val_accuracy: 0.3750 - val_loss: 1.3423
# Epoch 33/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.4476 - loss: 1.1765 - val_accuracy: 0.3750 - val_loss: 1.3355
# Epoch 34/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5182 - loss: 1.2326 - val_accuracy: 0.3750 - val_loss: 1.3310
# Epoch 35/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6535 - loss: 1.0065 - val_accuracy: 0.3750 - val_loss: 1.3292
# Epoch 36/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5783 - loss: 1.0127 - val_accuracy: 0.4167 - val_loss: 1.3260
# Epoch 37/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6027 - loss: 1.1836 - val_accuracy: 0.3750 - val_loss: 1.3181
# Epoch 38/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5897 - loss: 1.0836 - val_accuracy: 0.3750 - val_loss: 1.3087
# Epoch 39/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5587 - loss: 1.0249 - val_accuracy: 0.3750 - val_loss: 1.3001
# Epoch 40/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5700 - loss: 1.0744 - val_accuracy: 0.4167 - val_loss: 1.2943
# Epoch 41/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5608 - loss: 0.8992 - val_accuracy: 0.4167 - val_loss: 1.2882
# Epoch 42/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4405 - loss: 1.3073 - val_accuracy: 0.4167 - val_loss: 1.2844
# Epoch 43/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6971 - loss: 0.7961 - val_accuracy: 0.4167 - val_loss: 1.2813
# Epoch 44/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4199 - loss: 1.3227 - val_accuracy: 0.3750 - val_loss: 1.2762
# Epoch 45/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5910 - loss: 0.9601 - val_accuracy: 0.3750 - val_loss: 1.2737
# Epoch 46/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5950 - loss: 0.9926 - val_accuracy: 0.3750 - val_loss: 1.2695
# Epoch 47/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5854 - loss: 1.2997 - val_accuracy: 0.4167 - val_loss: 1.2656
# Epoch 48/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6066 - loss: 0.9458 - val_accuracy: 0.4583 - val_loss: 1.2629
# Epoch 49/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5597 - loss: 0.9901 - val_accuracy: 0.4167 - val_loss: 1.2639
# Epoch 50/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5919 - loss: 0.8729 - val_accuracy: 0.4583 - val_loss: 1.2631
# Epoch 51/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6002 - loss: 0.9165 - val_accuracy: 0.4583 - val_loss: 1.2610
# Epoch 52/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5654 - loss: 1.0711 - val_accuracy: 0.3750 - val_loss: 1.2573
# Epoch 53/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5827 - loss: 1.1238 - val_accuracy: 0.4167 - val_loss: 1.2533
# Epoch 54/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6362 - loss: 0.8704 - val_accuracy: 0.3750 - val_loss: 1.2486
# Epoch 55/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6116 - loss: 0.8346 - val_accuracy: 0.3333 - val_loss: 1.2455
# Epoch 56/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6442 - loss: 0.8250 - val_accuracy: 0.2917 - val_loss: 1.2438
# Epoch 57/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5783 - loss: 0.9532 - val_accuracy: 0.2917 - val_loss: 1.2432
# Epoch 58/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6233 - loss: 1.0471 - val_accuracy: 0.3333 - val_loss: 1.2413
# Epoch 59/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7619 - loss: 0.6973 - val_accuracy: 0.2917 - val_loss: 1.2435
# Epoch 60/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6073 - loss: 0.9719 - val_accuracy: 0.2917 - val_loss: 1.2468
# Epoch 61/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6427 - loss: 0.8280 - val_accuracy: 0.2917 - val_loss: 1.2499
# Epoch 62/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6994 - loss: 0.8102 - val_accuracy: 0.3333 - val_loss: 1.2522
# Epoch 63/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7150 - loss: 0.9169 - val_accuracy: 0.3333 - val_loss: 1.2558
# Epoch 64/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6173 - loss: 0.7930 - val_accuracy: 0.3333 - val_loss: 1.2615
# Epoch 65/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5789 - loss: 0.9925 - val_accuracy: 0.3333 - val_loss: 1.2649
# Epoch 66/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5816 - loss: 1.0360 - val_accuracy: 0.2917 - val_loss: 1.2680
# Epoch 67/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6260 - loss: 0.9527 - val_accuracy: 0.2500 - val_loss: 1.2670
# Epoch 68/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5946 - loss: 0.9959 - val_accuracy: 0.3333 - val_loss: 1.2640
# Epoch 69/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7111 - loss: 0.7182 - val_accuracy: 0.3333 - val_loss: 1.2645
# Epoch 70/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7161 - loss: 0.6366 - val_accuracy: 0.3333 - val_loss: 1.2666
# Epoch 71/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6769 - loss: 0.8061 - val_accuracy: 0.3333 - val_loss: 1.2689
# Epoch 72/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7148 - loss: 0.8801 - val_accuracy: 0.3333 - val_loss: 1.2671
# Epoch 73/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6152 - loss: 0.9449 - val_accuracy: 0.3333 - val_loss: 1.2688
# Epoch 74/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6685 - loss: 0.8619 - val_accuracy: 0.2917 - val_loss: 1.2765
# Epoch 75/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6765 - loss: 0.8140 - val_accuracy: 0.2917 - val_loss: 1.2835
# Epoch 76/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6790 - loss: 0.7703 - val_accuracy: 0.2917 - val_loss: 1.2896
# Epoch 77/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7188 - loss: 0.7529 - val_accuracy: 0.2917 - val_loss: 1.2966
# Epoch 78/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8059 - loss: 0.5463 - val_accuracy: 0.3333 - val_loss: 1.3026
# Epoch 79/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7730 - loss: 0.7195 - val_accuracy: 0.3750 - val_loss: 1.3029
# Epoch 80/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6331 - loss: 0.8793 - val_accuracy: 0.3750 - val_loss: 1.2990
# Epoch 81/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7027 - loss: 0.8004 - val_accuracy: 0.3750 - val_loss: 1.2938
# Epoch 82/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7263 - loss: 0.6681 - val_accuracy: 0.3750 - val_loss: 1.2911
# Epoch 83/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5966 - loss: 0.9544 - val_accuracy: 0.3750 - val_loss: 1.2910
# Epoch 84/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6212 - loss: 0.8845 - val_accuracy: 0.3750 - val_loss: 1.2886
# Epoch 85/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6019 - loss: 0.9851 - val_accuracy: 0.3750 - val_loss: 1.2850
# Epoch 86/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6279 - loss: 0.7507 - val_accuracy: 0.3750 - val_loss: 1.2837
# Epoch 87/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6758 - loss: 0.7080 - val_accuracy: 0.3750 - val_loss: 1.2856
# Epoch 88/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6961 - loss: 0.7066 - val_accuracy: 0.3750 - val_loss: 1.2895
# Epoch 89/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6615 - loss: 0.7673 - val_accuracy: 0.3750 - val_loss: 1.2945
# Epoch 90/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7154 - loss: 0.7620 - val_accuracy: 0.3750 - val_loss: 1.3001
# Epoch 91/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7048 - loss: 0.7112 - val_accuracy: 0.3750 - val_loss: 1.3074
# Epoch 92/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6744 - loss: 0.6922 - val_accuracy: 0.3750 - val_loss: 1.3103
# Epoch 93/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7565 - loss: 0.5961 - val_accuracy: 0.3750 - val_loss: 1.3164
# Epoch 94/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6854 - loss: 0.7161 - val_accuracy: 0.3750 - val_loss: 1.3282
# Epoch 95/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7057 - loss: 0.7038 - val_accuracy: 0.3750 - val_loss: 1.3386
# Epoch 96/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6781 - loss: 0.7950 - val_accuracy: 0.3750 - val_loss: 1.3503
# Epoch 97/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7261 - loss: 0.6911 - val_accuracy: 0.3750 - val_loss: 1.3629
# Epoch 98/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7323 - loss: 0.6682 - val_accuracy: 0.3750 - val_loss: 1.3783
# Epoch 99/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6638 - loss: 0.7159 - val_accuracy: 0.3750 - val_loss: 1.3890
# Epoch 100/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6665 - loss: 0.7549 - val_accuracy: 0.3750 - val_loss: 1.3990
# Epoch 101/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6129 - loss: 0.7903 - val_accuracy: 0.4167 - val_loss: 1.4027
# Epoch 102/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7063 - loss: 0.7139 - val_accuracy: 0.4167 - val_loss: 1.4058
# Epoch 103/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7569 - loss: 0.6718 - val_accuracy: 0.4167 - val_loss: 1.4158
# Epoch 104/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6135 - loss: 0.8481 - val_accuracy: 0.3750 - val_loss: 1.4168
# Epoch 105/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7423 - loss: 0.7083 - val_accuracy: 0.4167 - val_loss: 1.4232
# Epoch 106/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7071 - loss: 0.6919 - val_accuracy: 0.4167 - val_loss: 1.4289
# Epoch 107/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8005 - loss: 0.5107 - val_accuracy: 0.4167 - val_loss: 1.4390
# Epoch 108/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8005 - loss: 0.6111 - val_accuracy: 0.4167 - val_loss: 1.4426
# Epoch 109/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7855 - loss: 0.5839 - val_accuracy: 0.3750 - val_loss: 1.4476
# Epoch 110/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7004 - loss: 0.7839 - val_accuracy: 0.3750 - val_loss: 1.4521
# Epoch 111/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8334 - loss: 0.4424 - val_accuracy: 0.3750 - val_loss: 1.4579
# Epoch 112/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8165 - loss: 0.5554 - val_accuracy: 0.3750 - val_loss: 1.4689
# Epoch 113/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6838 - loss: 0.7061 - val_accuracy: 0.3750 - val_loss: 1.4749
# Epoch 114/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7169 - loss: 0.6719 - val_accuracy: 0.3750 - val_loss: 1.4867
# Epoch 115/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7463 - loss: 0.6264 - val_accuracy: 0.3750 - val_loss: 1.4899
# Epoch 116/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7177 - loss: 0.6296 - val_accuracy: 0.4167 - val_loss: 1.4825
# Epoch 117/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7153 - loss: 0.6871 - val_accuracy: 0.4167 - val_loss: 1.4940
# Epoch 118/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7686 - loss: 0.5485 - val_accuracy: 0.4167 - val_loss: 1.5004
# Epoch 119/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7642 - loss: 0.6843 - val_accuracy: 0.4167 - val_loss: 1.4896
# Epoch 120/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7390 - loss: 0.6569 - val_accuracy: 0.4167 - val_loss: 1.4979
# Epoch 121/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7872 - loss: 0.5932 - val_accuracy: 0.4167 - val_loss: 1.5131
# Epoch 122/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7988 - loss: 0.6016 - val_accuracy: 0.4583 - val_loss: 1.5256
# Epoch 123/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8384 - loss: 0.5878 - val_accuracy: 0.4167 - val_loss: 1.5268
# Epoch 124/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7815 - loss: 0.5149 - val_accuracy: 0.4167 - val_loss: 1.5424
# Epoch 125/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8172 - loss: 0.5618 - val_accuracy: 0.4167 - val_loss: 1.5540
# Epoch 126/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7942 - loss: 0.5119 - val_accuracy: 0.3750 - val_loss: 1.5649
# Epoch 127/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.7015 - loss: 0.6493 - val_accuracy: 0.3750 - val_loss: 1.5771
# Epoch 128/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7107 - loss: 0.6535 - val_accuracy: 0.3750 - val_loss: 1.5892
# Epoch 129/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7003 - loss: 0.6120 - val_accuracy: 0.3750 - val_loss: 1.5924
# Epoch 130/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7811 - loss: 0.4623 - val_accuracy: 0.3750 - val_loss: 1.6042
# Epoch 131/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7386 - loss: 0.6544 - val_accuracy: 0.3750 - val_loss: 1.6278
# Epoch 132/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7692 - loss: 0.6171 - val_accuracy: 0.3750 - val_loss: 1.6530
# Epoch 133/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8328 - loss: 0.5467 - val_accuracy: 0.3750 - val_loss: 1.6786
# Epoch 134/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8574 - loss: 0.4409 - val_accuracy: 0.3750 - val_loss: 1.6905
# Epoch 135/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.7327 - loss: 0.6963 - val_accuracy: 0.3750 - val_loss: 1.6922
# Epoch 136/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6621 - loss: 0.6914 - val_accuracy: 0.3750 - val_loss: 1.6828
# Epoch 137/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6811 - loss: 0.7526 - val_accuracy: 0.3750 - val_loss: 1.6800
# Epoch 138/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7626 - loss: 0.5663 - val_accuracy: 0.3750 - val_loss: 1.6776
# Epoch 139/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7909 - loss: 0.5810 - val_accuracy: 0.4167 - val_loss: 1.6779
# Epoch 140/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7776 - loss: 0.5657 - val_accuracy: 0.4167 - val_loss: 1.6878
# Epoch 141/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7645 - loss: 0.5421 - val_accuracy: 0.4583 - val_loss: 1.6974
# Epoch 142/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7755 - loss: 0.5261 - val_accuracy: 0.4583 - val_loss: 1.7019
# Epoch 143/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7261 - loss: 0.6755 - val_accuracy: 0.4167 - val_loss: 1.7056
# Epoch 144/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8101 - loss: 0.4672 - val_accuracy: 0.4167 - val_loss: 1.7071
# Epoch 145/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8397 - loss: 0.4312 - val_accuracy: 0.4167 - val_loss: 1.7176
# Epoch 146/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8134 - loss: 0.6142 - val_accuracy: 0.4167 - val_loss: 1.7249
# Epoch 147/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7772 - loss: 0.5032 - val_accuracy: 0.4167 - val_loss: 1.7420
# Epoch 148/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7305 - loss: 0.7933 - val_accuracy: 0.4167 - val_loss: 1.7536
# Epoch 149/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8278 - loss: 0.4655 - val_accuracy: 0.4167 - val_loss: 1.7749
# Epoch 150/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8251 - loss: 0.5076 - val_accuracy: 0.4167 - val_loss: 1.8065
# Epoch 151/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8061 - loss: 0.6186 - val_accuracy: 0.3750 - val_loss: 1.8223
# Epoch 152/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8414 - loss: 0.4592 - val_accuracy: 0.4167 - val_loss: 1.8340
# Epoch 153/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8059 - loss: 0.5304 - val_accuracy: 0.4167 - val_loss: 1.8512
# Epoch 154/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8368 - loss: 0.6121 - val_accuracy: 0.4167 - val_loss: 1.8490
# Epoch 155/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8224 - loss: 0.6262 - val_accuracy: 0.4167 - val_loss: 1.8376
# Epoch 156/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7619 - loss: 0.5219 - val_accuracy: 0.4583 - val_loss: 1.8363
# Epoch 157/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7299 - loss: 0.5224 - val_accuracy: 0.5000 - val_loss: 1.8379
# Epoch 158/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7580 - loss: 0.5474 - val_accuracy: 0.4583 - val_loss: 1.8412
# Epoch 159/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7315 - loss: 0.5985 - val_accuracy: 0.4583 - val_loss: 1.8505
# Epoch 160/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8657 - loss: 0.3884 - val_accuracy: 0.4583 - val_loss: 1.8660
# Epoch 161/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8866 - loss: 0.4833 - val_accuracy: 0.4583 - val_loss: 1.8804
# Epoch 162/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7453 - loss: 0.6622 - val_accuracy: 0.4583 - val_loss: 1.8934
# Epoch 163/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7918 - loss: 0.4851 - val_accuracy: 0.4167 - val_loss: 1.9209
# Epoch 164/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8045 - loss: 0.4255 - val_accuracy: 0.4583 - val_loss: 1.9403
# Epoch 165/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8201 - loss: 0.5910 - val_accuracy: 0.4167 - val_loss: 1.9484
# Epoch 166/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7659 - loss: 0.4818 - val_accuracy: 0.4167 - val_loss: 1.9587
# Epoch 167/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7709 - loss: 0.5088 - val_accuracy: 0.4167 - val_loss: 1.9734
# Epoch 168/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7267 - loss: 0.6405 - val_accuracy: 0.4167 - val_loss: 1.9803
# Epoch 169/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7795 - loss: 0.6644 - val_accuracy: 0.4167 - val_loss: 1.9964
# Epoch 170/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8474 - loss: 0.5296 - val_accuracy: 0.5000 - val_loss: 2.0180
# Epoch 171/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7203 - loss: 0.6996 - val_accuracy: 0.4583 - val_loss: 2.0500
# Epoch 172/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7638 - loss: 0.5756 - val_accuracy: 0.4583 - val_loss: 2.0606
# Epoch 173/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7888 - loss: 0.6142 - val_accuracy: 0.4167 - val_loss: 2.0549
# Epoch 174/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7813 - loss: 0.5043 - val_accuracy: 0.4167 - val_loss: 2.0565
# Epoch 175/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8530 - loss: 0.3707 - val_accuracy: 0.4167 - val_loss: 2.0582
# Epoch 176/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.6888 - loss: 0.6544 - val_accuracy: 0.4167 - val_loss: 2.0739
# Epoch 177/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.7044 - loss: 0.5843 - val_accuracy: 0.3750 - val_loss: 2.0827
# Epoch 178/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - accuracy: 0.8464 - loss: 0.4332 - val_accuracy: 0.3750 - val_loss: 2.0971
# Epoch 179/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8530 - loss: 0.4671 - val_accuracy: 0.3750 - val_loss: 2.1071
# Epoch 180/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.7799 - loss: 0.5657 - val_accuracy: 0.3750 - val_loss: 2.1209
# Epoch 181/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.8284 - loss: 0.3842 - val_accuracy: 0.3750 - val_loss: 2.1048
# Epoch 182/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9172 - loss: 0.3751 - val_accuracy: 0.3750 - val_loss: 2.1077
# Epoch 183/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8318 - loss: 0.4082 - val_accuracy: 0.4167 - val_loss: 2.1105
# Epoch 184/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7715 - loss: 0.5625 - val_accuracy: 0.4167 - val_loss: 2.1196
# Epoch 185/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8347 - loss: 0.4361 - val_accuracy: 0.4167 - val_loss: 2.1151
# Epoch 186/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.8051 - loss: 0.5520 - val_accuracy: 0.3750 - val_loss: 2.1334
# Epoch 187/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - accuracy: 0.8191 - loss: 0.4951 - val_accuracy: 0.3750 - val_loss: 2.1423
# Epoch 188/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - accuracy: 0.8584 - loss: 0.3713 - val_accuracy: 0.3750 - val_loss: 2.1526
# Epoch 189/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8368 - loss: 0.4622 - val_accuracy: 0.3750 - val_loss: 2.1721
# Epoch 190/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8241 - loss: 0.4920 - val_accuracy: 0.3750 - val_loss: 2.1884
# Epoch 191/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8255 - loss: 0.4111 - val_accuracy: 0.3750 - val_loss: 2.1964
# Epoch 192/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - accuracy: 0.9176 - loss: 0.3229 - val_accuracy: 0.3750 - val_loss: 2.1959
# Epoch 193/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.7432 - loss: 0.6341 - val_accuracy: 0.3750 - val_loss: 2.2240
# Epoch 194/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7576 - loss: 0.5599 - val_accuracy: 0.3750 - val_loss: 2.2332
# Epoch 195/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8228 - loss: 0.3755 - val_accuracy: 0.3750 - val_loss: 2.2331
# Epoch 196/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.7565 - loss: 0.5386 - val_accuracy: 0.3750 - val_loss: 2.2201
# Epoch 197/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.7809 - loss: 0.4445 - val_accuracy: 0.3750 - val_loss: 2.2041
# Epoch 198/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7851 - loss: 0.5479 - val_accuracy: 0.3333 - val_loss: 2.1988
# Epoch 199/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8218 - loss: 0.4550 - val_accuracy: 0.3333 - val_loss: 2.1995
# Epoch 200/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7480 - loss: 0.4979 - val_accuracy: 0.3333 - val_loss: 2.1939
# Epoch 201/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.8424 - loss: 0.4536 - val_accuracy: 0.3333 - val_loss: 2.1885
# Epoch 202/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.8480 - loss: 0.4024 - val_accuracy: 0.3333 - val_loss: 2.1653
# Epoch 203/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7399 - loss: 0.5576 - val_accuracy: 0.3333 - val_loss: 2.1574
# Epoch 204/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7895 - loss: 0.5102 - val_accuracy: 0.3750 - val_loss: 2.1555
# Epoch 205/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8803 - loss: 0.3835 - val_accuracy: 0.3750 - val_loss: 2.1626
# Epoch 206/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8353 - loss: 0.5247 - val_accuracy: 0.3750 - val_loss: 2.1612
# Epoch 207/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8403 - loss: 0.4879 - val_accuracy: 0.4167 - val_loss: 2.1616
# Epoch 208/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8364 - loss: 0.3643 - val_accuracy: 0.4167 - val_loss: 2.1614
# Epoch 209/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8597 - loss: 0.4916 - val_accuracy: 0.4167 - val_loss: 2.1672
# Epoch 210/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8261 - loss: 0.4741 - val_accuracy: 0.4167 - val_loss: 2.1750
# Epoch 211/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8364 - loss: 0.4179 - val_accuracy: 0.4167 - val_loss: 2.1864
# Epoch 212/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.7753 - loss: 0.5740 - val_accuracy: 0.4167 - val_loss: 2.1944
# Epoch 213/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.7838 - loss: 0.4578 - val_accuracy: 0.3750 - val_loss: 2.2242
# Epoch 214/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8374 - loss: 0.4432 - val_accuracy: 0.3750 - val_loss: 2.2464
# Epoch 215/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8045 - loss: 0.4950 - val_accuracy: 0.3750 - val_loss: 2.2670
# Epoch 216/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.7968 - loss: 0.3961 - val_accuracy: 0.3750 - val_loss: 2.2620
# Epoch 217/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.7849 - loss: 0.4873 - val_accuracy: 0.4167 - val_loss: 2.2683
# Epoch 218/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7961 - loss: 0.4299 - val_accuracy: 0.4167 - val_loss: 2.2601
# Epoch 219/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8065 - loss: 0.4061 - val_accuracy: 0.4167 - val_loss: 2.2475
# Epoch 220/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7353 - loss: 0.4214 - val_accuracy: 0.3750 - val_loss: 2.2387
# Epoch 221/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8437 - loss: 0.5300 - val_accuracy: 0.3750 - val_loss: 2.2258
# Epoch 222/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8593 - loss: 0.3691 - val_accuracy: 0.3750 - val_loss: 2.2186
# Epoch 223/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9216 - loss: 0.2453 - val_accuracy: 0.4167 - val_loss: 2.2140
# Epoch 224/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7559 - loss: 0.4642 - val_accuracy: 0.3750 - val_loss: 2.2195
# Epoch 225/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8401 - loss: 0.3749 - val_accuracy: 0.4167 - val_loss: 2.2287
# Epoch 226/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8822 - loss: 0.3512 - val_accuracy: 0.3750 - val_loss: 2.2439
# Epoch 227/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8660 - loss: 0.4105 - val_accuracy: 0.3750 - val_loss: 2.2560
# Epoch 228/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8883 - loss: 0.3495 - val_accuracy: 0.3750 - val_loss: 2.2729
# Epoch 229/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7888 - loss: 0.4998 - val_accuracy: 0.3750 - val_loss: 2.2897
# Epoch 230/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8191 - loss: 0.3724 - val_accuracy: 0.3750 - val_loss: 2.2923
# Epoch 231/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8474 - loss: 0.4181 - val_accuracy: 0.4167 - val_loss: 2.3013
# Epoch 232/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8057 - loss: 0.4596 - val_accuracy: 0.4167 - val_loss: 2.3038
# Epoch 233/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8580 - loss: 0.3530 - val_accuracy: 0.4167 - val_loss: 2.2960
# Epoch 234/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8797 - loss: 0.3164 - val_accuracy: 0.4583 - val_loss: 2.2894
# Epoch 235/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8178 - loss: 0.5162 - val_accuracy: 0.4167 - val_loss: 2.2878
# Epoch 236/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8224 - loss: 0.5050 - val_accuracy: 0.4167 - val_loss: 2.3037
# Epoch 237/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7576 - loss: 0.5782 - val_accuracy: 0.4167 - val_loss: 2.3074
# Epoch 238/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8251 - loss: 0.4230 - val_accuracy: 0.4167 - val_loss: 2.3171
# Epoch 239/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8184 - loss: 0.4559 - val_accuracy: 0.4583 - val_loss: 2.3113
# Epoch 240/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8568 - loss: 0.4345 - val_accuracy: 0.4583 - val_loss: 2.2952
# Epoch 241/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8128 - loss: 0.3626 - val_accuracy: 0.4583 - val_loss: 2.2993
# Epoch 242/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7596 - loss: 0.6772 - val_accuracy: 0.4583 - val_loss: 2.3065
# Epoch 243/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8464 - loss: 0.4553 - val_accuracy: 0.5000 - val_loss: 2.2912
# Epoch 244/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8730 - loss: 0.3413 - val_accuracy: 0.5000 - val_loss: 2.2747
# Epoch 245/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9012 - loss: 0.2823 - val_accuracy: 0.5833 - val_loss: 2.2503
# Epoch 246/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8322 - loss: 0.4512 - val_accuracy: 0.5417 - val_loss: 2.2375
# Epoch 247/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8297 - loss: 0.4406 - val_accuracy: 0.5417 - val_loss: 2.2222
# Epoch 248/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8480 - loss: 0.3668 - val_accuracy: 0.5000 - val_loss: 2.2014
# Epoch 249/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8703 - loss: 0.2981 - val_accuracy: 0.5417 - val_loss: 2.1929
# Epoch 250/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8341 - loss: 0.4455 - val_accuracy: 0.5417 - val_loss: 2.2074
# Epoch 251/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8664 - loss: 0.3903 - val_accuracy: 0.5417 - val_loss: 2.2248
# Epoch 252/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7955 - loss: 0.4933 - val_accuracy: 0.5000 - val_loss: 2.2364
# Epoch 253/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8447 - loss: 0.4251 - val_accuracy: 0.5000 - val_loss: 2.2596
# Epoch 254/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8797 - loss: 0.3569 - val_accuracy: 0.5000 - val_loss: 2.2772
# Epoch 255/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8111 - loss: 0.4631 - val_accuracy: 0.5000 - val_loss: 2.3012
# Epoch 256/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8710 - loss: 0.3810 - val_accuracy: 0.4583 - val_loss: 2.3251
# Epoch 257/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8337 - loss: 0.4593 - val_accuracy: 0.4583 - val_loss: 2.3515
# Epoch 258/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8983 - loss: 0.3481 - val_accuracy: 0.4167 - val_loss: 2.3683
# Epoch 259/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7555 - loss: 0.4889 - val_accuracy: 0.4167 - val_loss: 2.3808
# Epoch 260/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8937 - loss: 0.3254 - val_accuracy: 0.4167 - val_loss: 2.3790
# Epoch 261/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8251 - loss: 0.3971 - val_accuracy: 0.4167 - val_loss: 2.3743
# Epoch 262/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8491 - loss: 0.3882 - val_accuracy: 0.4167 - val_loss: 2.3735
# Epoch 263/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7907 - loss: 0.3829 - val_accuracy: 0.4167 - val_loss: 2.3720
# Epoch 264/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9080 - loss: 0.2873 - val_accuracy: 0.3750 - val_loss: 2.3727
# Epoch 265/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.8889 - loss: 0.3427 - val_accuracy: 0.3750 - val_loss: 2.3799
# Epoch 266/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8487 - loss: 0.3399 - val_accuracy: 0.3750 - val_loss: 2.3771
# Epoch 267/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8883 - loss: 0.2904 - val_accuracy: 0.3750 - val_loss: 2.3837
# Epoch 268/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9579 - loss: 0.2755 - val_accuracy: 0.4167 - val_loss: 2.4048
# Epoch 269/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8856 - loss: 0.3646 - val_accuracy: 0.4167 - val_loss: 2.4107
# Epoch 270/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8670 - loss: 0.3584 - val_accuracy: 0.3750 - val_loss: 2.4203
# Epoch 271/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9335 - loss: 0.2505 - val_accuracy: 0.3750 - val_loss: 2.4301
# Epoch 272/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8880 - loss: 0.2900 - val_accuracy: 0.4167 - val_loss: 2.4421
# Epoch 273/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7778 - loss: 0.4983 - val_accuracy: 0.4583 - val_loss: 2.4519
# Epoch 274/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9006 - loss: 0.3999 - val_accuracy: 0.4583 - val_loss: 2.4729
# Epoch 275/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9006 - loss: 0.3029 - val_accuracy: 0.4583 - val_loss: 2.4850
# Epoch 276/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8856 - loss: 0.4564 - val_accuracy: 0.4583 - val_loss: 2.4972
# Epoch 277/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8849 - loss: 0.3094 - val_accuracy: 0.4583 - val_loss: 2.5041
# Epoch 278/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8261 - loss: 0.4630 - val_accuracy: 0.4583 - val_loss: 2.4876
# Epoch 279/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8620 - loss: 0.4175 - val_accuracy: 0.4583 - val_loss: 2.4519
# Epoch 280/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8018 - loss: 0.4677 - val_accuracy: 0.4583 - val_loss: 2.4282
# Epoch 281/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8580 - loss: 0.4115 - val_accuracy: 0.4583 - val_loss: 2.3963
# Epoch 282/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8697 - loss: 0.3855 - val_accuracy: 0.4583 - val_loss: 2.3755
# Epoch 283/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8107 - loss: 0.3744 - val_accuracy: 0.4583 - val_loss: 2.3742
# Epoch 284/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8770 - loss: 0.3180 - val_accuracy: 0.4583 - val_loss: 2.3688
# Epoch 285/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8533 - loss: 0.3091 - val_accuracy: 0.4583 - val_loss: 2.3770
# Epoch 286/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8224 - loss: 0.4295 - val_accuracy: 0.4583 - val_loss: 2.3849
# Epoch 287/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9391 - loss: 0.2715 - val_accuracy: 0.4583 - val_loss: 2.3932
# Epoch 288/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7801 - loss: 0.4656 - val_accuracy: 0.4583 - val_loss: 2.4152
# Epoch 289/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8993 - loss: 0.2921 - val_accuracy: 0.4167 - val_loss: 2.4416
# Epoch 290/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9372 - loss: 0.2176 - val_accuracy: 0.4167 - val_loss: 2.4530
# Epoch 291/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8716 - loss: 0.3384 - val_accuracy: 0.4167 - val_loss: 2.4586
# Epoch 292/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8480 - loss: 0.3674 - val_accuracy: 0.5000 - val_loss: 2.4628
# Epoch 293/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9133 - loss: 0.2809 - val_accuracy: 0.4583 - val_loss: 2.4613
# Epoch 294/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8826 - loss: 0.3791 - val_accuracy: 0.5000 - val_loss: 2.4569
# Epoch 295/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8960 - loss: 0.3040 - val_accuracy: 0.5000 - val_loss: 2.4554
# Epoch 296/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7792 - loss: 0.4725 - val_accuracy: 0.5000 - val_loss: 2.4665
# Epoch 297/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8953 - loss: 0.3007 - val_accuracy: 0.5000 - val_loss: 2.4716
# Epoch 298/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8341 - loss: 0.3341 - val_accuracy: 0.5417 - val_loss: 2.4812
# Epoch 299/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8620 - loss: 0.3428 - val_accuracy: 0.5000 - val_loss: 2.4835
# Epoch 300/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8893 - loss: 0.2861 - val_accuracy: 0.5000 - val_loss: 2.4965

# %%
# Your comments about the change in performance

# %% [markdown]
# The training loss steadily decreases, and the training accuracy approaches nearly 100%.
# The validation loss starts off decreasing but then increases significantly over time, while the validation accuracy hovers around 40–50%. This gap between training and validation metrics remains large, suggesting that the model still struggles to generalize.
# The addition of Dropout and Batch Normalization has not fully resolved the overfitting issue, as evidenced by the large discrepancy between training and validation performance.

# %% [markdown]
# Experiment with different activation functions (ReLU, LeakyReLU, Tanh, Sigmoid) to observe their impact on model performance.

# %%
# Your code here:
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
import numpy as np

y_train_onehot = to_categorical(y_train.astype('category').cat.codes)
y_test_onehot = to_categorical(y_test.astype('category').cat.codes)

feature_count = preprocessor(X_train).shape[1]

def build_model(activation='relu'):
    """
    Build a simple feed-forward network that uses the specified activation function
    in its hidden layers. For LeakyReLU, we demonstrate how to add it manually.
    """
    model = Sequential()

    # First layer:
    if activation.lower() == 'leakyrelu':
        model.add(Dense(128, input_dim=feature_count))
        model.add(LeakyReLU(alpha=0.1))  # alpha is the negative slope
    else:
        model.add(Dense(128, input_dim=feature_count, activation=activation))

    # Optional
    model.add(BatchNormalization())
    model.add(Dropout(0.3))

    # Second hidden layer
    if activation.lower() == 'leakyrelu':
        model.add(Dense(64))
        model.add(LeakyReLU(alpha=0.1))
    else:
        model.add(Dense(64, activation=activation))

    model.add(BatchNormalization())
    model.add(Dropout(0.3))

    # Third hidden layer
    if activation.lower() == 'leakyrelu':
        model.add(Dense(32))
        model.add(LeakyReLU(alpha=0.1))
    else:
        model.add(Dense(32, activation=activation))

    model.add(BatchNormalization())
    model.add(Dropout(0.3))

    # Output layer (5 classes, Softmax)
    model.add(Dense(5, activation='softmax'))

    # Compile with Adam optimizer and categorical crossentropy
    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model


# List of activation functions to try
activations = ['relu', 'leakyrelu', 'tanh', 'sigmoid']

results = {}
epochs = 50
batch_size = 32

for act in activations:
    print(f"Training with activation = {act}")
    model = build_model(activation=act)

    history = model.fit(
        preprocessor(X_train),
        y_train_onehot,
        epochs=epochs,
        batch_size=batch_size,
        validation_split=0.2,
        verbose=0
    )

    test_loss, test_acc = model.evaluate(preprocessor(X_test), y_test_onehot, verbose=0)

    results[act] = {
        'train_acc': history.history['accuracy'][-1],
        'val_acc': history.history['val_accuracy'][-1],
        'test_acc': test_acc
    }
    print(f"--> Final train_acc: {results[act]['train_acc']:.4f}, "
          f"val_acc: {results[act]['val_acc']:.4f}, "
          f"test_acc: {results[act]['test_acc']:.4f}\n")

print("Summary of Activation Function Experiments:")
for act, metrics in results.items():
    print(f"Activation: {act}\n"
          f"  - Train Accuracy: {metrics['train_acc']:.4f}\n"
          f"  - Val Accuracy:   {metrics['val_acc']:.4f}\n"
          f"  - Test Accuracy:  {metrics['test_acc']:.4f}\n")
# Out:
# Training with activation = relu
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# --> Final train_acc: 0.6053, val_acc: 0.3684, test_acc: 0.4762
#
# Training with activation = leakyrelu
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# --> Final train_acc: 0.6711, val_acc: 0.1579, test_acc: 0.5238
#
# Training with activation = tanh
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# --> Final train_acc: 0.6053, val_acc: 0.2632, test_acc: 0.4524
#
# Training with activation = sigmoid
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# --> Final train_acc: 0.6053, val_acc: 0.2105, test_acc: 0.3095
#
# Summary of Activation Function Experiments:
# Activation: relu
#   - Train Accuracy: 0.6053
#   - Val Accuracy:   0.3684
#   - Test Accuracy:  0.4762
#
# Activation: leakyrelu
#   - Train Accuracy: 0.6711
#   - Val Accuracy:   0.1579
#   - Test Accuracy:  0.5238
#
# Activation: tanh
#   - Train Accuracy: 0.6053
#   - Val Accuracy:   0.2632
#   - Test Accuracy:  0.4524
#
# Activation: sigmoid
#   - Train Accuracy: 0.6053
#   - Val Accuracy:   0.2105
#   - Test Accuracy:  0.3095

# %% [markdown]
# ## 8. Explainability - SHAP Feature Importance
#
# To better understand our model's predictions, we will use **SHAP (SHapley Additive exPlanations)** to analyze feature importance.
#
# ### 🔹 How SHAP Works?
# - SHAP assigns each feature a **contribution score** for every prediction.
# - Uses **Shapley values** (from game theory) to fairly distribute importance across features.
#
# We will now apply SHAP to visualize and interpret our model’s feature contributions.

# %%
# !pip install shap
# Out:
# Requirement already satisfied: shap in /usr/local/lib/python3.11/dist-packages (0.46.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from shap) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from shap) (1.13.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from shap) (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from shap) (2.2.2)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.11/dist-packages (from shap) (4.67.1)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.11/dist-packages (from shap) (24.2)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.11/dist-packages (from shap) (0.0.8)
# Requirement already satisfied: numba in /usr/local/lib/python3.11/dist-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from shap) (3.1.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba->shap) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->shap) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->shap) (2025.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->shap) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)

# %%
import shap
import matplotlib.pyplot as plt

explainer = shap.Explainer(keras_model, X_test_transformed)

shap_values = explainer(X_test_transformed)

feature_names = [f"Feature_{i}" for i in range(X_test_transformed.shape[1])]

shap.summary_plot(shap_values[:, :, 0], X_test_transformed, feature_names=feature_names)
# Out:
# PermutationExplainer explainer: 43it [00:12,  1.74s/it]

# %% [markdown]
# <h3> Experimentation

# %%
print("SHAP values shape:", shap_values.values.shape)
# Out:
# SHAP values shape: (42, 17, 5)

# %% [markdown]
# **Deep learning models are often considered 'black boxes' due to their complexity. Explore methods such as SHAP (SHapley Additive exPlanations) to explain your model's predictions. After applying one of these methods, do you feel it provides a clear and sufficient explanation of how your model makes decisions? How easy or difficult is it to justify your model's predictions using these techniques?**

# %% [markdown]
# SHAP is a powerful tool for opening up the "black box" of deep learning models by attributing a contribution value to each feature for every prediction. In my experiment:
#
# Clarity of Explanation:
# SHAP’s summary plots, force plots, and dependence plots provide a visual and quantitative breakdown of how each feature influences the model's output. This can be quite illuminating—for example, a summary plot shows which features have the highest average impact on the model’s predictions, while a force plot can explain an individual prediction in detail.
#
# Sufficiency:
# While SHAP does a good job of highlighting the key features and their contribution scores, it may not always offer a fully "transparent" explanation of every internal mechanism. Deep learning models have complex, nonlinear interactions, and SHAP simplifies this into additive contributions. For many practical purposes, however, this level of explanation is both clear and sufficient.
#
# Ease of Justification:
# The ease with which one can justify a model’s predictions using SHAP depends on the complexity of the model and the domain. For simpler models or when using a well-tuned network, SHAP can provide very intuitive explanations. In contrast, for very deep models with many layers and interactions, the resulting SHAP values can be more difficult to interpret because multiple features might interact in subtle ways. Additionally, explaining these contributions to non-technical stakeholders sometimes requires further simplification or contextual explanation.
#
# Overall, I find that SHAP greatly improves the interpretability of deep learning models, even though it might not capture every nuance of the model’s internal workings. It offers a practical balance between interpretability and the inherent complexity of deep models, making it a valuable tool for justifying model predictions.

# %% [markdown]
# ## 9. Submission of final report and clean code to github
#
# [This is a final project you display on your GitHub to the World]
#
# **Instructions**
# - Make a new notebook, visualize any plots you found relevant
# - Reproduce the code you used for the best models and display results
# - Write what insights you found useful and what behaviours were observed
# - Make it in a style of a clean, succint report (within the .ipynb)
# - Upload this final report notebook to a new repository in your personal github account
# - Remember to paste the link of your final repo at the top of this notebook where asked
